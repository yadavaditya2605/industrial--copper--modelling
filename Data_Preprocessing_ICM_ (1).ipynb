# %% [markdown]
# # **Problem Statement [Click](https://docs.google.com/document/d/1nWKUnD6F76F1AtGFEjyfIVH9oxcBUU1N/edit)**

# %% [markdown]
# # **Data Collection :**

# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\DINESH KUMAR\\Downloads\\Copper_Set.csv")
# Out:
# C:\Users\DINESH KUMAR\AppData\Local\Temp\ipykernel_15364\888342677.py:3: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:\\Users\\DINESH KUMAR\\Downloads\\Copper_Set.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181673 entries, 0 to 181672
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             181671 non-null  object
#  1   item_date      181672 non-null  float64
#  2   quantity tons  181673 non-null  object
#  3   customer       181672 non-null  float64
#  4   country        181645 non-null  float64
#  5   status         181671 non-null  object
#  6   item type      181673 non-null  object
#  7   application    181649 non-null  float64
#  8   thickness      181672 non-null  float64
#  9   width          181673 non-null  float64
#  10  material_ref   103754 non-null  object
#  11  product_ref    181673 non-null  int64
#  12  delivery date  181672 non-null  float64
#  13  selling_price  181672 non-null  float64
# dtypes: float64(8), int64(1), object(5)
# memory usage: 19.4+ MB

# %%
df.head()
# Out:
#                                      id   item_date quantity tons    customer  \
# 0  EC06F063-9DF0-440C-8764-0B0C05A4F6AE  20210401.0     54.151139  30156308.0
# 1  4E5F4B3D-DDDF-499D-AFDE-A3227EC49425  20210401.0    768.024839  30202938.0
# 2  E140FF1B-2407-4C02-A0DD-780A093B1158  20210401.0    386.127949  30153963.0
# 3  F8D507A0-9C62-4EFE-831E-33E1DA53BB50  20210401.0    202.411065  30349574.0
# 4  4E1C4E78-152B-430A-8094-ADD889C9D0AD  20210401.0    785.526262  30211560.0
#
#    country status item type  application  thickness   width  \
# 0     28.0    Won         W         10.0       2.00  1500.0
# 1     25.0    Won         W         41.0       0.80  1210.0
# 2     30.0    Won        WI         28.0       0.38   952.0
# 3     32.0    Won         S         59.0       2.30  1317.0
# 4     28.0    Won         W         10.0       4.00  2000.0
#
#                                material_ref  product_ref  delivery date  \
# 0                               DEQ1 S460MC   1670798778     20210701.0
# 1  0000000000000000000000000000000000104991   1668701718     20210401.0
# 2                                  S0380700       628377     20210101.0
# 3                   DX51D+ZM310MAO 2.3X1317   1668701718     20210101.0
# 4                           2_S275JR+AR-CL1       640665     20210301.0
#
#    selling_price
# 0         854.00
# 1        1047.00
# 2         644.33
# 3         768.00
# 4         577.00

# %%
copydf = df.copy()

# %%
copydf.head()
# Out:
#                                      id   item_date quantity tons    customer  \
# 0  EC06F063-9DF0-440C-8764-0B0C05A4F6AE  20210401.0     54.151139  30156308.0
# 1  4E5F4B3D-DDDF-499D-AFDE-A3227EC49425  20210401.0    768.024839  30202938.0
# 2  E140FF1B-2407-4C02-A0DD-780A093B1158  20210401.0    386.127949  30153963.0
# 3  F8D507A0-9C62-4EFE-831E-33E1DA53BB50  20210401.0    202.411065  30349574.0
# 4  4E1C4E78-152B-430A-8094-ADD889C9D0AD  20210401.0    785.526262  30211560.0
#
#    country status item type  application  thickness   width  \
# 0     28.0    Won         W         10.0       2.00  1500.0
# 1     25.0    Won         W         41.0       0.80  1210.0
# 2     30.0    Won        WI         28.0       0.38   952.0
# 3     32.0    Won         S         59.0       2.30  1317.0
# 4     28.0    Won         W         10.0       4.00  2000.0
#
#                                material_ref  product_ref  delivery date  \
# 0                               DEQ1 S460MC   1670798778     20210701.0
# 1  0000000000000000000000000000000000104991   1668701718     20210401.0
# 2                                  S0380700       628377     20210101.0
# 3                   DX51D+ZM310MAO 2.3X1317   1668701718     20210101.0
# 4                           2_S275JR+AR-CL1       640665     20210301.0
#
#    selling_price
# 0         854.00
# 1        1047.00
# 2         644.33
# 3         768.00
# 4         577.00

# %% [markdown]
# # **Data Preprocess :**

# %% [markdown]
# **`Object Creation For Ordinal Encoder`**

# %%
# Convert Categorical data into continous data

from sklearn.preprocessing import OrdinalEncoder

encoder = OrdinalEncoder()

# %%
copydf.columns
# Out:
# Index(['id', 'item_date', 'quantity tons', 'customer', 'country', 'status',
#        'item type', 'application', 'thickness', 'width', 'material_ref',
#        'product_ref', 'delivery date', 'selling_price'],
#       dtype='object')

# %%
copydf.columns = ['id', 'item_date', 'quantity_tons', 'customer', 'country', 'status',
       'item_type', 'application', 'thickness', 'width', 'material_ref',
       'product_ref', 'delivery_date', 'selling_price']

# %% [markdown]
# **`Missing value Count`**

# %%
copydf.isnull().mean()*100  # See Percentage of the missing values
# Out:
# id                0.001101
# item_date         0.000550
# quantity_tons     0.000000
# customer          0.000550
# country           0.015412
# status            0.001101
# item_type         0.000000
# application       0.013211
# thickness         0.000550
# width             0.000000
# material_ref     42.889697
# product_ref       0.000000
# delivery_date     0.000550
# selling_price     0.000550
# dtype: float64

# %% [markdown]
# **`Before Cleaning Process`**

# %%
copydf.isnull().sum() # See total missing values for corresponding columns
# Out:
# id                   2
# item_date            1
# quantity_tons        0
# customer             1
# country             28
# status               2
# item_type            0
# application         24
# thickness            1
# width                0
# material_ref     77919
# product_ref          0
# delivery_date        1
# selling_price        1
# dtype: int64

# %%
print(f'Total missing value : {copydf.isnull().sum().sum()}') # Overall missing value count
# Out:
# Total missing value : 77980

# %% [markdown]
# **`Column Data Types`**

# %%
copydf.dtypes
# Out:
# id                object
# item_date        float64
# quantity_tons     object
# customer         float64
# country          float64
# status            object
# item_type         object
# application      float64
# thickness        float64
# width            float64
# material_ref      object
# product_ref        int64
# delivery_date    float64
# selling_price    float64
# dtype: object

# %% [markdown]
# **`Data Cleaning :`**

# %% [markdown]
# **Treat missing value for 'id' column**

# %%
copydf['id'] = copydf['id'].apply(lambda x : str(x))    # String conversion

copydf['id'].fillna(method='bfill',inplace=True)

print('Total Missing Value :',copydf['id'].isnull().sum())
# Out:
# Total Missing Value : 0

# %% [markdown]
# **Treat missing value for 'item_date' column**

# %%
copydf['item_date'].fillna(method='bfill',inplace=True) # Missing value Filled

copydf['item_date'] = copydf['item_date'].apply(lambda x : str(float(x))) # String Conversion

copydf['item_date'] = copydf['item_date'].apply(lambda x : f'{x[0:4]}-{x[4:6]}-{x[6:8]}')

copydf['item_date_day'] = copydf['item_date'].apply(lambda x : x[8:])

copydf['item_date'] = copydf['item_date'].apply(lambda x :  pd.to_datetime(f'{x[0:4]}-01-01',format='%Y-%m-%d')  if x[5:7] == '00' or x[8:] == '00' or int(x[5:7]) > 12 else pd.to_datetime(x,format='%Y-%m-%d')) # Date format Conversion

copydf['item_date_year'] = pd.to_datetime(copydf['item_date']).dt.year

copydf['item_date_month'] = pd.to_datetime(copydf['item_date']).dt.month

print('Total Missing Value :',copydf['item_date'].isnull().sum())
# Out:
# Total Missing Value : 0

# %% [markdown]
# **Treat Missing Value for "quantity_tons" column**

# %%
copydf['quantity_tons'] = copydf['quantity_tons'].apply(lambda x : float('1000.00') if x == 'e' else float(x))

print('Total Missing Value :',copydf['quantity_tons'].isnull().sum())
# Out:
# Total Missing Value : 0

# %% [markdown]
# **'customer' column**

# %%
copydf['customer'] = copydf['customer'].apply(lambda x : str(x))

copydf['customer'] = copydf['customer'].apply(lambda x : x.split('.'))

copydf['customer'] = copydf['customer'].apply(lambda x : x[0])

# %%
copydf.dtypes
# Out:
# id                         object
# item_date          datetime64[ns]
# quantity_tons             float64
# customer                   object
# country                   float64
# status                     object
# item_type                  object
# application               float64
# thickness                 float64
# width                     float64
# material_ref               object
# product_ref                 int64
# delivery_date             float64
# selling_price             float64
# item_date_day              object
# item_date_year              int64
# item_date_month             int64
# dtype: object

# %% [markdown]
# **Collecting only 'WON' and 'LOST' Status Feature**

# %%
copydf
# Out:
#                                           id  item_date  quantity_tons  \
# 0       EC06F063-9DF0-440C-8764-0B0C05A4F6AE 2021-04-01      54.151139
# 1       4E5F4B3D-DDDF-499D-AFDE-A3227EC49425 2021-04-01     768.024839
# 2       E140FF1B-2407-4C02-A0DD-780A093B1158 2021-04-01     386.127949
# 3       F8D507A0-9C62-4EFE-831E-33E1DA53BB50 2021-04-01     202.411065
# 4       4E1C4E78-152B-430A-8094-ADD889C9D0AD 2021-04-01     785.526262
# ...                                      ...        ...            ...
# 181668  DE633116-D1DF-4846-982E-55EFC3658A76 2020-07-02     102.482422
# 181669  A48374B1-E6DB-45F2-889A-1F9C27C099EB 2020-07-02     208.086469
# 181670  91643238-5C7B-4237-9A5F-63AE3D35F320 2020-07-02       4.235594
# 181671  7AFFD323-01D9-4E15-B80D-7D1B03498FC8 2020-07-02   -2000.000000
# 181672  AD0CA853-AE3C-4B2F-9FBB-8B0B965F84BC 2020-07-02     406.686538
#
#         customer  country status item_type  application  thickness   width  \
# 0       30156308     28.0    Won         W         10.0       2.00  1500.0
# 1       30202938     25.0    Won         W         41.0       0.80  1210.0
# 2       30153963     30.0    Won        WI         28.0       0.38   952.0
# 3       30349574     32.0    Won         S         59.0       2.30  1317.0
# 4       30211560     28.0    Won         W         10.0       4.00  2000.0
# ...          ...      ...    ...       ...          ...        ...     ...
# 181668  30200854     25.0    Won         W         41.0       0.96  1220.0
# 181669  30200854     25.0    Won         W         41.0       0.95  1500.0
# 181670  30200854     25.0    Won         W         41.0       0.71  1250.0
# 181671  30200854     25.0    Won         W         41.0       0.85  1250.0
# 181672  30200854     25.0    Won         W         41.0       0.71  1240.0
#
#                                     material_ref  product_ref  delivery_date  \
# 0                                    DEQ1 S460MC   1670798778     20210701.0
# 1       0000000000000000000000000000000000104991   1668701718     20210401.0
# 2                                       S0380700       628377     20210101.0
# 3                        DX51D+ZM310MAO 2.3X1317   1668701718     20210101.0
# 4                                2_S275JR+AR-CL1       640665     20210301.0
# ...                                          ...          ...            ...
# 181668  0000000000000000000000000000000001000777    164141591     20200701.0
# 181669  0000000000000000000000000000000001000227    164141591     20200701.0
# 181670  0000000000000000000000000000000001004216    164141591     20200701.0
# 181671  0000000000000000000000000000000001001149    164141591     20200701.0
# 181672  0000000000000000000000000000000001005439    164141591     20200701.0
#
#         selling_price item_date_day  item_date_year  item_date_month
# 0              854.00            01            2021                4
# 1             1047.00            01            2021                4
# 2              644.33            01            2021                4
# 3              768.00            01            2021                4
# 4              577.00            01            2021                4
# ...               ...           ...             ...              ...
# 181668         591.00            02            2020                7
# 181669         589.00            02            2020                7
# 181670         619.00            02            2020                7
# 181671         601.00            02            2020                7
# 181672         607.00            02            2020                7
#
# [181673 rows x 17 columns]

# %%
copydf = copydf.drop(['id','material_ref'],axis=1)

new_df = copydf.query('status == "Won" or status == "Lost"')

new_df = copydf.copy()

# %%
new_df
# Out:
#         item_date  quantity_tons  customer  country status item_type  \
# 0      2021-04-01      54.151139  30156308     28.0    Won         W
# 1      2021-04-01     768.024839  30202938     25.0    Won         W
# 2      2021-04-01     386.127949  30153963     30.0    Won        WI
# 3      2021-04-01     202.411065  30349574     32.0    Won         S
# 4      2021-04-01     785.526262  30211560     28.0    Won         W
# ...           ...            ...       ...      ...    ...       ...
# 181668 2020-07-02     102.482422  30200854     25.0    Won         W
# 181669 2020-07-02     208.086469  30200854     25.0    Won         W
# 181670 2020-07-02       4.235594  30200854     25.0    Won         W
# 181671 2020-07-02   -2000.000000  30200854     25.0    Won         W
# 181672 2020-07-02     406.686538  30200854     25.0    Won         W
#
#         application  thickness   width  product_ref  delivery_date  \
# 0              10.0       2.00  1500.0   1670798778     20210701.0
# 1              41.0       0.80  1210.0   1668701718     20210401.0
# 2              28.0       0.38   952.0       628377     20210101.0
# 3              59.0       2.30  1317.0   1668701718     20210101.0
# 4              10.0       4.00  2000.0       640665     20210301.0
# ...             ...        ...     ...          ...            ...
# 181668         41.0       0.96  1220.0    164141591     20200701.0
# 181669         41.0       0.95  1500.0    164141591     20200701.0
# 181670         41.0       0.71  1250.0    164141591     20200701.0
# 181671         41.0       0.85  1250.0    164141591     20200701.0
# 181672         41.0       0.71  1240.0    164141591     20200701.0
#
#         selling_price item_date_day  item_date_year  item_date_month
# 0              854.00            01            2021                4
# 1             1047.00            01            2021                4
# 2              644.33            01            2021                4
# 3              768.00            01            2021                4
# 4              577.00            01            2021                4
# ...               ...           ...             ...              ...
# 181668         591.00            02            2020                7
# 181669         589.00            02            2020                7
# 181670         619.00            02            2020                7
# 181671         601.00            02            2020                7
# 181672         607.00            02            2020                7
#
# [181673 rows x 15 columns]

# %% [markdown]
# **'Country' Column**

# %%
new_df.isnull().sum()
# Out:
# item_date           0
# quantity_tons       0
# customer            0
# country            28
# status              2
# item_type           0
# application        24
# thickness           1
# width               0
# product_ref         0
# delivery_date       1
# selling_price       1
# item_date_day       0
# item_date_year      0
# item_date_month     0
# dtype: int64

# %%
new_df = new_df.dropna(subset=['country'])
new_df = new_df.dropna(subset=['status'])
new_df = new_df.dropna(subset=['thickness'])
new_df = new_df.dropna(subset=['selling_price'])
new_df = new_df.dropna(subset=['delivery_date'])

# %%
new_df.isnull().sum()
# Out:
# item_date          0
# quantity_tons      0
# customer           0
# country            0
# status             0
# item_type          0
# application        0
# thickness          0
# width              0
# product_ref        0
# delivery_date      0
# selling_price      0
# item_date_day      0
# item_date_year     0
# item_date_month    0
# dtype: int64

# %% [markdown]
# **'Status' Column**

# %%
# Before Conversion

new_df['status'].unique()
# Out:
# array(['Won', 'Draft', 'To be approved', 'Lost', 'Not lost for AM',
#        'Wonderful', 'Revised', 'Offered', 'Offerable'], dtype=object)

# %%
# Conversion Process

new_df['status'] = new_df['status'].map({'Won':1, 'Draft':2, 'To be approved':3, 'Lost':0, 'Not lost for AM':5,
       'Wonderful':6, 'Revised':7, 'Offered':8, 'Offerable':4})

# %%
# After Conversion

new_df['status'].unique()
# Out:
# array([1, 2, 3, 0, 5, 6, 7, 8, 4], dtype=int64)

# %% [markdown]
# **'item_type' Column**

# %%
# Before Converion

new_df['item_type'].unique()
# Out:
# array(['W', 'WI', 'S', 'Others', 'PL', 'IPL', 'SLAWR'], dtype=object)

# %%
# Conversion Process

new_df['item_type'] = encoder.fit_transform(new_df[['item_type']])

# %%
# After Conversion

new_df['item_type'].unique()
# Out:
# array([5., 6., 3., 1., 2., 0., 4.])

# %% [markdown]
# **'application' Column**

# %%
new_df['application'].unique()
# Out:
# array([10., 41., 28., 59., 15.,  4., 38., 56., 42., 26., 27., 19., 20.,
#        66., 29., 22., 40., 25., 67., 79.,  3., 99.,  2.,  5., 39., 69.,
#        70., 65., 58., 68.])

# %%
new_df['application'].fillna(method='bfill',inplace=True)

new_df['application'] = new_df['application'].apply(lambda x : float(x))

# %% [markdown]
# **'thickness' Column**

# %%
new_df['thickness'] = new_df['thickness'].apply(lambda x : float(x))

# %% [markdown]
# **'width' Column**

# %%
new_df['width'] = new_df['width'].apply(lambda x : float(x))

# %%
new_df.isnull().sum()
# Out:
# item_date          0
# quantity_tons      0
# customer           0
# country            0
# status             0
# item_type          0
# application        0
# thickness          0
# width              0
# product_ref        0
# delivery_date      0
# selling_price      0
# item_date_day      0
# item_date_year     0
# item_date_month    0
# dtype: int64

# %% [markdown]
# **'product_ref' Column**

# %%
new_df['product_ref'] = new_df['product_ref'] .apply(lambda x : str(x))

# %% [markdown]
# **'delivery date' Column**

# %%
new_df
# Out:
#         item_date  quantity_tons  customer  country  status  item_type  \
# 0      2021-04-01      54.151139  30156308     28.0       1        5.0
# 1      2021-04-01     768.024839  30202938     25.0       1        5.0
# 2      2021-04-01     386.127949  30153963     30.0       1        6.0
# 3      2021-04-01     202.411065  30349574     32.0       1        3.0
# 4      2021-04-01     785.526262  30211560     28.0       1        5.0
# ...           ...            ...       ...      ...     ...        ...
# 181668 2020-07-02     102.482422  30200854     25.0       1        5.0
# 181669 2020-07-02     208.086469  30200854     25.0       1        5.0
# 181670 2020-07-02       4.235594  30200854     25.0       1        5.0
# 181671 2020-07-02   -2000.000000  30200854     25.0       1        5.0
# 181672 2020-07-02     406.686538  30200854     25.0       1        5.0
#
#         application  thickness   width product_ref  delivery_date  \
# 0              10.0       2.00  1500.0  1670798778     20210701.0
# 1              41.0       0.80  1210.0  1668701718     20210401.0
# 2              28.0       0.38   952.0      628377     20210101.0
# 3              59.0       2.30  1317.0  1668701718     20210101.0
# 4              10.0       4.00  2000.0      640665     20210301.0
# ...             ...        ...     ...         ...            ...
# 181668         41.0       0.96  1220.0   164141591     20200701.0
# 181669         41.0       0.95  1500.0   164141591     20200701.0
# 181670         41.0       0.71  1250.0   164141591     20200701.0
# 181671         41.0       0.85  1250.0   164141591     20200701.0
# 181672         41.0       0.71  1240.0   164141591     20200701.0
#
#         selling_price item_date_day  item_date_year  item_date_month
# 0              854.00            01            2021                4
# 1             1047.00            01            2021                4
# 2              644.33            01            2021                4
# 3              768.00            01            2021                4
# 4              577.00            01            2021                4
# ...               ...           ...             ...              ...
# 181668         591.00            02            2020                7
# 181669         589.00            02            2020                7
# 181670         619.00            02            2020                7
# 181671         601.00            02            2020                7
# 181672         607.00            02            2020                7
#
# [181640 rows x 15 columns]

# %%
new_df['delivery_date'].fillna(method='bfill',inplace=True) # Missing value Filled

new_df['delivery_date'] = new_df['delivery_date'].apply(lambda x : str(x)) # String Conversion

new_df['delivery_date'] = new_df['delivery_date'].apply(lambda x : f'{x[0:4]}-{x[4:6]}-{x[6:8]}')

new_df['delivery_date'] = new_df['delivery_date'].apply(lambda x : '2023-01-01'   if  int(x[:4]) > 2023  else x)

new_df['delivery_date_day'] = new_df['delivery_date'].apply(lambda x : int(x[8:]))

new_df['delivery_date'] = new_df['delivery_date'].apply(lambda x : f'{x[:4]}-12-{x[8:]}'   if  int(x[5:7]) > 12  else x)

new_df['delivery_date'] = pd.to_datetime(new_df['delivery_date']) # Date format Conversion

new_df['delivery_date_month'] = pd.to_datetime(new_df['delivery_date']).dt.month

new_df['delivery_date_year'] = pd.to_datetime(new_df['delivery_date']).dt.year

# %%
new_df.dtypes
# Out:
# item_date              datetime64[ns]
# quantity_tons                 float64
# customer                       object
# country                       float64
# status                          int64
# item_type                     float64
# application                   float64
# thickness                     float64
# width                         float64
# product_ref                    object
# delivery_date          datetime64[ns]
# selling_price                 float64
# item_date_day                  object
# item_date_year                  int64
# item_date_month                 int64
# delivery_date_day               int64
# delivery_date_month             int64
# delivery_date_year              int64
# dtype: object

# %% [markdown]
# **Selling Price Column**

# %%
Mean = round(new_df['selling_price'].mean(),3)

new_df['selling_price'].fillna(Mean,inplace=True)

new_df['selling_price'] = new_df['selling_price'].apply(lambda x : float(x))

# %%
new_df.isnull().sum()
# Out:
# item_date              0
# quantity_tons          0
# customer               0
# country                0
# status                 0
# item_type              0
# application            0
# thickness              0
# width                  0
# product_ref            0
# delivery_date          0
# selling_price          0
# item_date_day          0
# item_date_year         0
# item_date_month        0
# delivery_date_day      0
# delivery_date_month    0
# delivery_date_year     0
# dtype: int64

# %%
new_df
# Out:
#         item_date  quantity_tons  customer  country  status  item_type  \
# 0      2021-04-01      54.151139  30156308     28.0       1        5.0
# 1      2021-04-01     768.024839  30202938     25.0       1        5.0
# 2      2021-04-01     386.127949  30153963     30.0       1        6.0
# 3      2021-04-01     202.411065  30349574     32.0       1        3.0
# 4      2021-04-01     785.526262  30211560     28.0       1        5.0
# ...           ...            ...       ...      ...     ...        ...
# 181668 2020-07-02     102.482422  30200854     25.0       1        5.0
# 181669 2020-07-02     208.086469  30200854     25.0       1        5.0
# 181670 2020-07-02       4.235594  30200854     25.0       1        5.0
# 181671 2020-07-02   -2000.000000  30200854     25.0       1        5.0
# 181672 2020-07-02     406.686538  30200854     25.0       1        5.0
#
#         application  thickness   width product_ref delivery_date  \
# 0              10.0       2.00  1500.0  1670798778    2021-07-01
# 1              41.0       0.80  1210.0  1668701718    2021-04-01
# 2              28.0       0.38   952.0      628377    2021-01-01
# 3              59.0       2.30  1317.0  1668701718    2021-01-01
# 4              10.0       4.00  2000.0      640665    2021-03-01
# ...             ...        ...     ...         ...           ...
# 181668         41.0       0.96  1220.0   164141591    2020-07-01
# 181669         41.0       0.95  1500.0   164141591    2020-07-01
# 181670         41.0       0.71  1250.0   164141591    2020-07-01
# 181671         41.0       0.85  1250.0   164141591    2020-07-01
# 181672         41.0       0.71  1240.0   164141591    2020-07-01
#
#         selling_price item_date_day  item_date_year  item_date_month  \
# 0              854.00            01            2021                4
# 1             1047.00            01            2021                4
# 2              644.33            01            2021                4
# 3              768.00            01            2021                4
# 4              577.00            01            2021                4
# ...               ...           ...             ...              ...
# 181668         591.00            02            2020                7
# 181669         589.00            02            2020                7
# 181670         619.00            02            2020                7
# 181671         601.00            02            2020                7
# 181672         607.00            02            2020                7
#
#         delivery_date_day  delivery_date_month  delivery_date_year
# 0                       1                    7                2021
# 1                       1                    4                2021
# 2                       1                    1                2021
# 3                       1                    1                2021
# 4                       1                    3                2021
# ...                   ...                  ...                 ...
# 181668                  1                    7                2020
# 181669                  1                    7                2020
# 181670                  1                    7                2020
# 181671                  1                    7                2020
# 181672                  1                    7                2020
#
# [181640 rows x 18 columns]

# %%
new_df['item_date_day'] = new_df['item_date_day'].apply(lambda x : int(x))

# %%
new_df['quantity_tons'] = new_df['quantity_tons'].apply(lambda x : 0.0  if x<0.0 else x)
new_df['selling_price'] = new_df['selling_price'].apply(lambda x : 0.0  if x<0.0 else x)

# %%
new_df
# Out:
#         item_date  quantity_tons  customer  country  status  item_type  \
# 0      2021-04-01      54.151139  30156308     28.0       1        5.0
# 1      2021-04-01     768.024839  30202938     25.0       1        5.0
# 2      2021-04-01     386.127949  30153963     30.0       1        6.0
# 3      2021-04-01     202.411065  30349574     32.0       1        3.0
# 4      2021-04-01     785.526262  30211560     28.0       1        5.0
# ...           ...            ...       ...      ...     ...        ...
# 181668 2020-07-02     102.482422  30200854     25.0       1        5.0
# 181669 2020-07-02     208.086469  30200854     25.0       1        5.0
# 181670 2020-07-02       4.235594  30200854     25.0       1        5.0
# 181671 2020-07-02       0.000000  30200854     25.0       1        5.0
# 181672 2020-07-02     406.686538  30200854     25.0       1        5.0
#
#         application  thickness   width product_ref delivery_date  \
# 0              10.0       2.00  1500.0  1670798778    2021-07-01
# 1              41.0       0.80  1210.0  1668701718    2021-04-01
# 2              28.0       0.38   952.0      628377    2021-01-01
# 3              59.0       2.30  1317.0  1668701718    2021-01-01
# 4              10.0       4.00  2000.0      640665    2021-03-01
# ...             ...        ...     ...         ...           ...
# 181668         41.0       0.96  1220.0   164141591    2020-07-01
# 181669         41.0       0.95  1500.0   164141591    2020-07-01
# 181670         41.0       0.71  1250.0   164141591    2020-07-01
# 181671         41.0       0.85  1250.0   164141591    2020-07-01
# 181672         41.0       0.71  1240.0   164141591    2020-07-01
#
#         selling_price  item_date_day  item_date_year  item_date_month  \
# 0              854.00              1            2021                4
# 1             1047.00              1            2021                4
# 2              644.33              1            2021                4
# 3              768.00              1            2021                4
# 4              577.00              1            2021                4
# ...               ...            ...             ...              ...
# 181668         591.00              2            2020                7
# 181669         589.00              2            2020                7
# 181670         619.00              2            2020                7
# 181671         601.00              2            2020                7
# 181672         607.00              2            2020                7
#
#         delivery_date_day  delivery_date_month  delivery_date_year
# 0                       1                    7                2021
# 1                       1                    4                2021
# 2                       1                    1                2021
# 3                       1                    1                2021
# 4                       1                    3                2021
# ...                   ...                  ...                 ...
# 181668                  1                    7                2020
# 181669                  1                    7                2020
# 181670                  1                    7                2020
# 181671                  1                    7                2020
# 181672                  1                    7                2020
#
# [181640 rows x 18 columns]

# %%
import seaborn as sns

import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(13,8))
sns.heatmap(new_df.corr(),annot=True)
# Out:
# C:\Users\DINESH KUMAR\AppData\Local\Temp\ipykernel_15364\3981604865.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(new_df.corr(),annot=True)
# <Axes: >

# %% [markdown]
# # **Treating Skewness**

# %%
new_df
# Out:
#         item_date  quantity_tons  customer  country  status  item_type  \
# 0      2021-04-01      54.151139  30156308     28.0       1        5.0
# 1      2021-04-01     768.024839  30202938     25.0       1        5.0
# 2      2021-04-01     386.127949  30153963     30.0       1        6.0
# 3      2021-04-01     202.411065  30349574     32.0       1        3.0
# 4      2021-04-01     785.526262  30211560     28.0       1        5.0
# ...           ...            ...       ...      ...     ...        ...
# 181668 2020-07-02     102.482422  30200854     25.0       1        5.0
# 181669 2020-07-02     208.086469  30200854     25.0       1        5.0
# 181670 2020-07-02       4.235594  30200854     25.0       1        5.0
# 181671 2020-07-02       0.000000  30200854     25.0       1        5.0
# 181672 2020-07-02     406.686538  30200854     25.0       1        5.0
#
#         application  thickness   width product_ref delivery_date  \
# 0              10.0       2.00  1500.0  1670798778    2021-07-01
# 1              41.0       0.80  1210.0  1668701718    2021-04-01
# 2              28.0       0.38   952.0      628377    2021-01-01
# 3              59.0       2.30  1317.0  1668701718    2021-01-01
# 4              10.0       4.00  2000.0      640665    2021-03-01
# ...             ...        ...     ...         ...           ...
# 181668         41.0       0.96  1220.0   164141591    2020-07-01
# 181669         41.0       0.95  1500.0   164141591    2020-07-01
# 181670         41.0       0.71  1250.0   164141591    2020-07-01
# 181671         41.0       0.85  1250.0   164141591    2020-07-01
# 181672         41.0       0.71  1240.0   164141591    2020-07-01
#
#         selling_price  item_date_day  item_date_year  item_date_month  \
# 0              854.00              1            2021                4
# 1             1047.00              1            2021                4
# 2              644.33              1            2021                4
# 3              768.00              1            2021                4
# 4              577.00              1            2021                4
# ...               ...            ...             ...              ...
# 181668         591.00              2            2020                7
# 181669         589.00              2            2020                7
# 181670         619.00              2            2020                7
# 181671         601.00              2            2020                7
# 181672         607.00              2            2020                7
#
#         delivery_date_day  delivery_date_month  delivery_date_year
# 0                       1                    7                2021
# 1                       1                    4                2021
# 2                       1                    1                2021
# 3                       1                    1                2021
# 4                       1                    3                2021
# ...                   ...                  ...                 ...
# 181668                  1                    7                2020
# 181669                  1                    7                2020
# 181670                  1                    7                2020
# 181671                  1                    7                2020
# 181672                  1                    7                2020
#
# [181640 rows x 18 columns]

# %%
columns = [ 'quantity_tons',  'application', 'thickness', 'width', 'selling_price', ]

# %% [markdown]
# # **Before Treating Skewness**

# %%
# from scipy.stats import norm
# def before_skewness(column):
#   for i in columns:
#     sns.set_style("darkgrid")
#     sns.histplot(new_df[i],kde=True,color='r')
#     plt.title(f'Skewness In {i}')
#     plt.show()

# before_skewness(columns)

# %% [markdown]
# # **After Treated The Skewness**

# %%
new_df_1 = new_df.copy()

# %% [markdown]
# **`Log Transoformation`**

# %%
columns
# Out:
# ['quantity_tons', 'application', 'thickness', 'width', 'selling_price']

# %%
import numpy as np
def log_transformation(column):
  for i in column:
    new_df_1[i] = np.log(new_df_1[i])

log_transformation(columns)
# Out:
# C:\Users\DINESH KUMAR\anaconda3\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
def before_skewness(column):
  for i in columns:
    sns.set_style("darkgrid")
    sns.histplot(new_df_1[i],kde=True,color='g')
    plt.title(f'Skewness In {i}')
    plt.show()

before_skewness(columns)

# %% [markdown]
# # **Treating Outliers With IQR Method**

# %%
new_df_1
# Out:
#         item_date  quantity_tons  customer  country  status  item_type  \
# 0      2021-04-01       3.991779  30156308     28.0       1        5.0
# 1      2021-04-01       6.643822  30202938     25.0       1        5.0
# 2      2021-04-01       5.956169  30153963     30.0       1        6.0
# 3      2021-04-01       5.310301  30349574     32.0       1        3.0
# 4      2021-04-01       6.666354  30211560     28.0       1        5.0
# ...           ...            ...       ...      ...     ...        ...
# 181668 2020-07-02       4.629691  30200854     25.0       1        5.0
# 181669 2020-07-02       5.337954  30200854     25.0       1        5.0
# 181670 2020-07-02       1.443523  30200854     25.0       1        5.0
# 181671 2020-07-02           -inf  30200854     25.0       1        5.0
# 181672 2020-07-02       6.008043  30200854     25.0       1        5.0
#
#         application  thickness     width product_ref delivery_date  \
# 0          2.302585   0.693147  7.313220  1670798778    2021-07-01
# 1          3.713572  -0.223144  7.098376  1668701718    2021-04-01
# 2          3.332205  -0.967584  6.858565      628377    2021-01-01
# 3          4.077537   0.832909  7.183112  1668701718    2021-01-01
# 4          2.302585   1.386294  7.600902      640665    2021-03-01
# ...             ...        ...       ...         ...           ...
# 181668     3.713572  -0.040822  7.106606   164141591    2020-07-01
# 181669     3.713572  -0.051293  7.313220   164141591    2020-07-01
# 181670     3.713572  -0.342490  7.130899   164141591    2020-07-01
# 181671     3.713572  -0.162519  7.130899   164141591    2020-07-01
# 181672     3.713572  -0.342490  7.122867   164141591    2020-07-01
#
#         selling_price  item_date_day  item_date_year  item_date_month  \
# 0            6.749931              1            2021                4
# 1            6.953684              1            2021                4
# 2            6.468211              1            2021                4
# 3            6.643790              1            2021                4
# 4            6.357842              1            2021                4
# ...               ...            ...             ...              ...
# 181668       6.381816              2            2020                7
# 181669       6.378426              2            2020                7
# 181670       6.428105              2            2020                7
# 181671       6.398595              2            2020                7
# 181672       6.408529              2            2020                7
#
#         delivery_date_day  delivery_date_month  delivery_date_year
# 0                       1                    7                2021
# 1                       1                    4                2021
# 2                       1                    1                2021
# 3                       1                    1                2021
# 4                       1                    3                2021
# ...                   ...                  ...                 ...
# 181668                  1                    7                2020
# 181669                  1                    7                2020
# 181670                  1                    7                2020
# 181671                  1                    7                2020
# 181672                  1                    7                2020
#
# [181640 rows x 18 columns]

# %% [markdown]
# # **Before Treating Outliers**

# %%
import seaborn as sns
import matplotlib.pyplot as plt


def box_plot(columns):

  for i in columns:
    sns.boxplot(data=new_df_1,x=i)
    plt.show()

box_plot(['quantity_tons','thickness','width','selling_price'])

# %% [markdown]
# # **After Treating Outliers**

# %%
import numpy as np

def treat_outliers(column):
  for i in column:
    iqr = np.percentile(new_df_1[i],75) - np.percentile(new_df_1[i],25)  # Q3 - Q1
    lower_bound =  np.percentile(new_df_1[i],25) - (1.5 * iqr)
    upper_bound = np.percentile(new_df_1[i],75) + (1.5 * iqr)
    new_df_1[i] = new_df_1[i].clip(lower_bound,upper_bound)
  print('Done !!!!')

treat_outliers(['quantity_tons','thickness','width','selling_price'])
# Out:
# Done !!!!

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def box_plot(columns):

  for i in columns:
    sns.boxplot(data=new_df_1,x=i)
    plt.show()

box_plot(['quantity_tons','thickness','width','selling_price'])

# %% [markdown]
# ```
# # Note : We cleared all the outliers values !!!
# ```

# %% [markdown]
# # **Handling Wrong Delivery Dates**

# %%
df
# Out:
#                                           id   item_date quantity tons  \
# 0       EC06F063-9DF0-440C-8764-0B0C05A4F6AE  20210401.0     54.151139
# 1       4E5F4B3D-DDDF-499D-AFDE-A3227EC49425  20210401.0    768.024839
# 2       E140FF1B-2407-4C02-A0DD-780A093B1158  20210401.0    386.127949
# 3       F8D507A0-9C62-4EFE-831E-33E1DA53BB50  20210401.0    202.411065
# 4       4E1C4E78-152B-430A-8094-ADD889C9D0AD  20210401.0    785.526262
# ...                                      ...         ...           ...
# 181668  DE633116-D1DF-4846-982E-55EFC3658A76  20200702.0   102.4824216
# 181669  A48374B1-E6DB-45F2-889A-1F9C27C099EB  20200702.0   208.0864686
# 181670  91643238-5C7B-4237-9A5F-63AE3D35F320  20200702.0   4.235593568
# 181671  7AFFD323-01D9-4E15-B80D-7D1B03498FC8  20200702.0         -2000
# 181672  AD0CA853-AE3C-4B2F-9FBB-8B0B965F84BC  20200702.0   406.6865384
#
#           customer  country status item type  application  thickness   width  \
# 0       30156308.0     28.0    Won         W         10.0       2.00  1500.0
# 1       30202938.0     25.0    Won         W         41.0       0.80  1210.0
# 2       30153963.0     30.0    Won        WI         28.0       0.38   952.0
# 3       30349574.0     32.0    Won         S         59.0       2.30  1317.0
# 4       30211560.0     28.0    Won         W         10.0       4.00  2000.0
# ...            ...      ...    ...       ...          ...        ...     ...
# 181668  30200854.0     25.0    Won         W         41.0       0.96  1220.0
# 181669  30200854.0     25.0    Won         W         41.0       0.95  1500.0
# 181670  30200854.0     25.0    Won         W         41.0       0.71  1250.0
# 181671  30200854.0     25.0    Won         W         41.0       0.85  1250.0
# 181672  30200854.0     25.0    Won         W         41.0       0.71  1240.0
#
#                                     material_ref  product_ref  delivery date  \
# 0                                    DEQ1 S460MC   1670798778     20210701.0
# 1       0000000000000000000000000000000000104991   1668701718     20210401.0
# 2                                       S0380700       628377     20210101.0
# 3                        DX51D+ZM310MAO 2.3X1317   1668701718     20210101.0
# 4                                2_S275JR+AR-CL1       640665     20210301.0
# ...                                          ...          ...            ...
# 181668  0000000000000000000000000000000001000777    164141591     20200701.0
# 181669  0000000000000000000000000000000001000227    164141591     20200701.0
# 181670  0000000000000000000000000000000001004216    164141591     20200701.0
# 181671  0000000000000000000000000000000001001149    164141591     20200701.0
# 181672  0000000000000000000000000000000001005439    164141591     20200701.0
#
#         selling_price
# 0              854.00
# 1             1047.00
# 2              644.33
# 3              768.00
# 4              577.00
# ...               ...
# 181668         591.00
# 181669         589.00
# 181670         619.00
# 181671         601.00
# 181672         607.00
#
# [181673 rows x 14 columns]

# %%
new_df_1
# Out:
#         item_date  quantity_tons  customer  country  status  item_type  \
# 0      2021-04-01       3.991779  30156308     28.0       1        5.0
# 1      2021-04-01       6.643822  30202938     25.0       1        5.0
# 2      2021-04-01       5.956169  30153963     30.0       1        6.0
# 3      2021-04-01       5.310301  30349574     32.0       1        3.0
# 4      2021-04-01       6.666354  30211560     28.0       1        5.0
# ...           ...            ...       ...      ...     ...        ...
# 181668 2020-07-02       4.629691  30200854     25.0       1        5.0
# 181669 2020-07-02       5.337954  30200854     25.0       1        5.0
# 181670 2020-07-02       1.443523  30200854     25.0       1        5.0
# 181671 2020-07-02      -0.323075  30200854     25.0       1        5.0
# 181672 2020-07-02       6.008043  30200854     25.0       1        5.0
#
#         application  thickness     width product_ref delivery_date  \
# 0          2.302585   0.693147  7.313220  1670798778    2021-07-01
# 1          3.713572  -0.223144  7.098376  1668701718    2021-04-01
# 2          3.332205  -0.967584  6.858565      628377    2021-01-01
# 3          4.077537   0.832909  7.183112  1668701718    2021-01-01
# 4          2.302585   1.386294  7.600902      640665    2021-03-01
# ...             ...        ...       ...         ...           ...
# 181668     3.713572  -0.040822  7.106606   164141591    2020-07-01
# 181669     3.713572  -0.051293  7.313220   164141591    2020-07-01
# 181670     3.713572  -0.342490  7.130899   164141591    2020-07-01
# 181671     3.713572  -0.162519  7.130899   164141591    2020-07-01
# 181672     3.713572  -0.342490  7.122867   164141591    2020-07-01
#
#         selling_price  item_date_day  item_date_year  item_date_month  \
# 0            6.749931              1            2021                4
# 1            6.953684              1            2021                4
# 2            6.468211              1            2021                4
# 3            6.643790              1            2021                4
# 4            6.357842              1            2021                4
# ...               ...            ...             ...              ...
# 181668       6.381816              2            2020                7
# 181669       6.378426              2            2020                7
# 181670       6.428105              2            2020                7
# 181671       6.398595              2            2020                7
# 181672       6.408529              2            2020                7
#
#         delivery_date_day  delivery_date_month  delivery_date_year
# 0                       1                    7                2021
# 1                       1                    4                2021
# 2                       1                    1                2021
# 3                       1                    1                2021
# 4                       1                    3                2021
# ...                   ...                  ...                 ...
# 181668                  1                    7                2020
# 181669                  1                    7                2020
# 181670                  1                    7                2020
# 181671                  1                    7                2020
# 181672                  1                    7                2020
#
# [181640 rows x 18 columns]

# %%
new_df_1['delivery_item_date_difference_num'] = (new_df_1['delivery_date']-new_df_1['item_date']).dt.days

# %%
positive = new_df_1[new_df_1['delivery_item_date_difference_num']>0]

# %%
len(positive)
# Out:
# 165073

# %%
new_df_1.corr()
# Out:
# C:\Users\DINESH KUMAR\AppData\Local\Temp\ipykernel_15364\683216786.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   new_df_1.corr()
#                                    quantity_tons   country    status  \
# quantity_tons                           1.000000 -0.090553  0.034578
# country                                -0.090553  1.000000 -0.035932
# status                                  0.034578 -0.035932  1.000000
# item_type                              -0.324754  0.129954 -0.082258
# application                             0.055706 -0.033796  0.067847
# thickness                               0.041169 -0.065251 -0.070415
# width                                   0.034730  0.052758 -0.043021
# selling_price                          -0.038993 -0.020073  0.036356
# item_date_day                           0.037436 -0.058935  0.003612
# item_date_year                         -0.008942 -0.016378 -0.001194
# item_date_month                        -0.001017  0.022838 -0.004364
# delivery_date_day                       0.000054 -0.001624 -0.000642
# delivery_date_month                    -0.019381  0.022657  0.031334
# delivery_date_year                      0.022001 -0.072048 -0.010619
# delivery_item_date_difference_num       0.060859 -0.178263  0.041400
#
#                                    item_type  application  thickness  \
# quantity_tons                      -0.324754     0.055706   0.041169
# country                             0.129954    -0.033796  -0.065251
# status                             -0.082258     0.067847  -0.070415
# item_type                           1.000000     0.176207  -0.101228
# application                         0.176207     1.000000  -0.225863
# thickness                          -0.101228    -0.225863   1.000000
# width                              -0.093742    -0.186293   0.378392
# selling_price                       0.095118     0.145437  -0.420918
# item_date_day                      -0.038792    -0.006602  -0.004677
# item_date_year                      0.053367    -0.012629   0.007379
# item_date_month                    -0.025606     0.015625  -0.007492
# delivery_date_day                  -0.002520     0.004122  -0.002491
# delivery_date_month                 0.007013     0.020163  -0.016801
# delivery_date_year                 -0.000377    -0.060764   0.039947
# delivery_item_date_difference_num  -0.106267    -0.150918   0.091102
#
#                                       width  selling_price  item_date_day  \
# quantity_tons                      0.034730      -0.038993       0.037436
# country                            0.052758      -0.020073      -0.058935
# status                            -0.043021       0.036356       0.003612
# item_type                         -0.093742       0.095118      -0.038792
# application                       -0.186293       0.145437      -0.006602
# thickness                          0.378392      -0.420918      -0.004677
# width                              1.000000      -0.160883      -0.001389
# selling_price                     -0.160883       1.000000      -0.001866
# item_date_day                     -0.001389      -0.001866       1.000000
# item_date_year                     0.019201       0.516128      -0.000461
# item_date_month                   -0.023778      -0.392326      -0.055407
# delivery_date_day                 -0.000275       0.000318      -0.000833
# delivery_date_month                0.014619      -0.163299       0.055971
# delivery_date_year                 0.007975       0.446844      -0.018668
# delivery_item_date_difference_num  0.044685       0.265650       0.012186
#
#                                    item_date_year  item_date_month  \
# quantity_tons                           -0.008942        -0.001017
# country                                 -0.016378         0.022838
# status                                  -0.001194        -0.004364
# item_type                                0.053367        -0.025606
# application                             -0.012629         0.015625
# thickness                                0.007379        -0.007492
# width                                    0.019201        -0.023778
# selling_price                            0.516128        -0.392326
# item_date_day                           -0.000461        -0.055407
# item_date_year                           1.000000        -0.924102
# item_date_month                         -0.924102         1.000000
# delivery_date_day                       -0.001863         0.002536
# delivery_date_month                     -0.102203        -0.070816
# delivery_date_year                       0.548514        -0.301945
# delivery_item_date_difference_num        0.281210        -0.245255
#
#                                    delivery_date_day  delivery_date_month  \
# quantity_tons                               0.000054            -0.019381
# country                                    -0.001624             0.022657
# status                                     -0.000642             0.031334
# item_type                                  -0.002520             0.007013
# application                                 0.004122             0.020163
# thickness                                  -0.002491            -0.016801
# width                                      -0.000275             0.014619
# selling_price                               0.000318            -0.163299
# item_date_day                              -0.000833             0.055971
# item_date_year                             -0.001863            -0.102203
# item_date_month                             0.002536            -0.070816
# delivery_date_day                           1.000000             0.004281
# delivery_date_month                         0.004281             1.000000
# delivery_date_year                          0.001628            -0.797631
# delivery_item_date_difference_num           0.015568            -0.111216
#
#                                    delivery_date_year  \
# quantity_tons                                0.022001
# country                                     -0.072048
# status                                      -0.010619
# item_type                                   -0.000377
# application                                 -0.060764
# thickness                                    0.039947
# width                                        0.007975
# selling_price                                0.446844
# item_date_day                               -0.018668
# item_date_year                               0.548514
# item_date_month                             -0.301945
# delivery_date_day                            0.001628
# delivery_date_month                         -0.797631
# delivery_date_year                           1.000000
# delivery_item_date_difference_num            0.495844
#
#                                    delivery_item_date_difference_num
# quantity_tons                                               0.060859
# country                                                    -0.178263
# status                                                      0.041400
# item_type                                                  -0.106267
# application                                                -0.150918
# thickness                                                   0.091102
# width                                                       0.044685
# selling_price                                               0.265650
# item_date_day                                               0.012186
# item_date_year                                              0.281210
# item_date_month                                            -0.245255
# delivery_date_day                                           0.015568
# delivery_date_month                                        -0.111216
# delivery_date_year                                          0.495844
# delivery_item_date_difference_num                           1.000000

# %%
new_df_1.head(2)
# Out:
#    item_date  quantity_tons  customer  country  status  item_type  \
# 0 2021-04-01       3.991779  30156308     28.0       1        5.0
# 1 2021-04-01       6.643822  30202938     25.0       1        5.0
#
#    application  thickness     width product_ref delivery_date  selling_price  \
# 0     2.302585   0.693147  7.313220  1670798778    2021-07-01       6.749931
# 1     3.713572  -0.223144  7.098376  1668701718    2021-04-01       6.953684
#
#    item_date_day  item_date_year  item_date_month  delivery_date_day  \
# 0              1            2021                4                  1
# 1              1            2021                4                  1
#
#    delivery_date_month  delivery_date_year  delivery_item_date_difference_num
# 0                    7                2021                                 91
# 1                    4                2021                                  0

# %% [markdown]
# **Model To Predict Delivery Date**

# %%
correct_delivery_dates_df = new_df_1.query('delivery_item_date_difference_num>0')

# %%
correct_delivery_dates_df
# Out:
#         item_date  quantity_tons  customer  country  status  item_type  \
# 0      2021-04-01       3.991779  30156308     28.0       1        5.0
# 6      2021-04-01       1.259203  30209509     30.0       2        5.0
# 8      2021-04-01       4.235147  30341428     38.0       1        3.0
# 10     2021-04-01       2.216566  30209509     30.0       2        5.0
# 12     2021-04-01       3.314642  30165529     78.0       1        5.0
# ...           ...            ...       ...      ...     ...        ...
# 181433 2020-07-02       3.472467  30227718     25.0       0        3.0
# 181525 2020-07-02       4.196171  30161559     30.0       0        3.0
# 181527 2020-07-02       4.156686  30161559     30.0       0        3.0
# 181529 2020-07-02       4.025862  30161559     30.0       0        3.0
# 181531 2020-07-02       5.328963  30161559     30.0       0        3.0
#
#         application  thickness     width product_ref delivery_date  \
# 0          2.302585   0.693147  7.313220  1670798778    2021-07-01
# 6          3.713572  -0.967584  7.025538      611993    2021-07-01
# 8          2.302585  -0.510826  7.150701  1668701376    2021-07-01
# 10         3.713572  -0.967584  7.025538      611993    2021-07-01
# 12         2.302585  -0.287682  7.130899   164141591    2021-07-01
# ...             ...        ...       ...         ...           ...
# 181433     2.708050   1.791759  7.600902      640665    2020-08-01
# 181525     2.302585   1.348073  7.329750      640665    2020-08-01
# 181527     2.302585   1.766442  7.329750      640665    2020-08-01
# 181529     2.302585   2.060514  7.313220      640665    2020-08-01
# 181531     2.302585   1.348073  7.512071      640665    2020-08-01
#
#         selling_price  item_date_day  item_date_year  item_date_month  \
# 0            6.749931              1            2021                4
# 6            5.975038              1            2021                4
# 8            7.217443              1            2021                4
# 10           5.975038              1            2021                4
# 12           7.001246              1            2021                4
# ...               ...            ...             ...              ...
# 181433       6.313548              2            2020                7
# 181525       6.126869              2            2020                7
# 181527       6.124683              2            2020                7
# 181529       6.126869              2            2020                7
# 181531       6.131226              2            2020                7
#
#         delivery_date_day  delivery_date_month  delivery_date_year  \
# 0                       1                    7                2021
# 6                       1                    7                2021
# 8                       1                    7                2021
# 10                      1                    7                2021
# 12                      1                    7                2021
# ...                   ...                  ...                 ...
# 181433                  1                    8                2020
# 181525                  1                    8                2020
# 181527                  1                    8                2020
# 181529                  1                    8                2020
# 181531                  1                    8                2020
#
#         delivery_item_date_difference_num
# 0                                      91
# 6                                      91
# 8                                      91
# 10                                     91
# 12                                     91
# ...                                   ...
# 181433                                 30
# 181525                                 30
# 181527                                 30
# 181529                                 30
# 181531                                 30
#
# [165073 rows x 19 columns]

# %%
wrong_delivery_dates_df = new_df_1.query('delivery_item_date_difference_num<=0')

# %%
wrong_delivery_dates_df
# Out:
#         item_date  quantity_tons  customer  country  status  item_type  \
# 1      2021-04-01       6.643822  30202938     25.0       1        5.0
# 2      2021-04-01       5.956169  30153963     30.0       1        6.0
# 3      2021-04-01       5.310301  30349574     32.0       1        3.0
# 4      2021-04-01       6.666354  30211560     28.0       1        5.0
# 5      2021-04-01       5.419608  30202938     25.0       1        5.0
# ...           ...            ...       ...      ...     ...        ...
# 181668 2020-07-02       4.629691  30200854     25.0       1        5.0
# 181669 2020-07-02       5.337954  30200854     25.0       1        5.0
# 181670 2020-07-02       1.443523  30200854     25.0       1        5.0
# 181671 2020-07-02      -0.323075  30200854     25.0       1        5.0
# 181672 2020-07-02       6.008043  30200854     25.0       1        5.0
#
#         application  thickness     width product_ref delivery_date  \
# 1          3.713572  -0.223144  7.098376  1668701718    2021-04-01
# 2          3.332205  -0.967584  6.858565      628377    2021-01-01
# 3          4.077537   0.832909  7.183112  1668701718    2021-01-01
# 4          2.302585   1.386294  7.600902      640665    2021-03-01
# 5          3.713572   0.405465  7.142827  1668701718    2021-04-01
# ...             ...        ...       ...         ...           ...
# 181668     3.713572  -0.040822  7.106606   164141591    2020-07-01
# 181669     3.713572  -0.051293  7.313220   164141591    2020-07-01
# 181670     3.713572  -0.342490  7.130899   164141591    2020-07-01
# 181671     3.713572  -0.162519  7.130899   164141591    2020-07-01
# 181672     3.713572  -0.342490  7.122867   164141591    2020-07-01
#
#         selling_price  item_date_day  item_date_year  item_date_month  \
# 1            6.953684              1            2021                4
# 2            6.468211              1            2021                4
# 3            6.643790              1            2021                4
# 4            6.357842              1            2021                4
# 5            6.890609              1            2021                4
# ...               ...            ...             ...              ...
# 181668       6.381816              2            2020                7
# 181669       6.378426              2            2020                7
# 181670       6.428105              2            2020                7
# 181671       6.398595              2            2020                7
# 181672       6.408529              2            2020                7
#
#         delivery_date_day  delivery_date_month  delivery_date_year  \
# 1                       1                    4                2021
# 2                       1                    1                2021
# 3                       1                    1                2021
# 4                       1                    3                2021
# 5                       1                    4                2021
# ...                   ...                  ...                 ...
# 181668                  1                    7                2020
# 181669                  1                    7                2020
# 181670                  1                    7                2020
# 181671                  1                    7                2020
# 181672                  1                    7                2020
#
#         delivery_item_date_difference_num
# 1                                       0
# 2                                     -90
# 3                                     -90
# 4                                     -31
# 5                                       0
# ...                                   ...
# 181668                                 -1
# 181669                                 -1
# 181670                                 -1
# 181671                                 -1
# 181672                                 -1
#
# [16567 rows x 19 columns]

# %%
correct_delivery_dates_df =  correct_delivery_dates_df.dropna()

# %%
correct_delivery_dates_df
# Out:
#         item_date  quantity_tons  customer  country  status  item_type  \
# 0      2021-04-01       3.991779  30156308     28.0       1        5.0
# 6      2021-04-01       1.259203  30209509     30.0       2        5.0
# 8      2021-04-01       4.235147  30341428     38.0       1        3.0
# 10     2021-04-01       2.216566  30209509     30.0       2        5.0
# 12     2021-04-01       3.314642  30165529     78.0       1        5.0
# ...           ...            ...       ...      ...     ...        ...
# 181433 2020-07-02       3.472467  30227718     25.0       0        3.0
# 181525 2020-07-02       4.196171  30161559     30.0       0        3.0
# 181527 2020-07-02       4.156686  30161559     30.0       0        3.0
# 181529 2020-07-02       4.025862  30161559     30.0       0        3.0
# 181531 2020-07-02       5.328963  30161559     30.0       0        3.0
#
#         application  thickness     width product_ref delivery_date  \
# 0          2.302585   0.693147  7.313220  1670798778    2021-07-01
# 6          3.713572  -0.967584  7.025538      611993    2021-07-01
# 8          2.302585  -0.510826  7.150701  1668701376    2021-07-01
# 10         3.713572  -0.967584  7.025538      611993    2021-07-01
# 12         2.302585  -0.287682  7.130899   164141591    2021-07-01
# ...             ...        ...       ...         ...           ...
# 181433     2.708050   1.791759  7.600902      640665    2020-08-01
# 181525     2.302585   1.348073  7.329750      640665    2020-08-01
# 181527     2.302585   1.766442  7.329750      640665    2020-08-01
# 181529     2.302585   2.060514  7.313220      640665    2020-08-01
# 181531     2.302585   1.348073  7.512071      640665    2020-08-01
#
#         selling_price  item_date_day  item_date_year  item_date_month  \
# 0            6.749931              1            2021                4
# 6            5.975038              1            2021                4
# 8            7.217443              1            2021                4
# 10           5.975038              1            2021                4
# 12           7.001246              1            2021                4
# ...               ...            ...             ...              ...
# 181433       6.313548              2            2020                7
# 181525       6.126869              2            2020                7
# 181527       6.124683              2            2020                7
# 181529       6.126869              2            2020                7
# 181531       6.131226              2            2020                7
#
#         delivery_date_day  delivery_date_month  delivery_date_year  \
# 0                       1                    7                2021
# 6                       1                    7                2021
# 8                       1                    7                2021
# 10                      1                    7                2021
# 12                      1                    7                2021
# ...                   ...                  ...                 ...
# 181433                  1                    8                2020
# 181525                  1                    8                2020
# 181527                  1                    8                2020
# 181529                  1                    8                2020
# 181531                  1                    8                2020
#
#         delivery_item_date_difference_num
# 0                                      91
# 6                                      91
# 8                                      91
# 10                                     91
# 12                                     91
# ...                                   ...
# 181433                                 30
# 181525                                 30
# 181527                                 30
# 181529                                 30
# 181531                                 30
#
# [165073 rows x 19 columns]

# %%
x = correct_delivery_dates_df[[ 'quantity_tons', 'customer', 'country', 'status',
       'item_type', 'application', 'thickness', 'width', 'product_ref',
        'selling_price', 'item_date_day', 'item_date_year',
       'item_date_month', 'delivery_date_day', 'delivery_date_month',
       'delivery_date_year',]]

y = correct_delivery_dates_df['delivery_item_date_difference_num']

# %%
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.impute import SimpleImputer


imputer = SimpleImputer(strategy='mean')


xtrain = imputer.fit_transform(xtrain)

# %%
from sklearn.ensemble import RandomForestRegressor

model =  RandomForestRegressor().fit(xtrain,ytrain)

# %%
from sklearn.impute import SimpleImputer


imputer = SimpleImputer(strategy='mean')


xtest = imputer.fit_transform(xtest)

# %%
# predict
from sklearn.metrics import r2_score

xtest = pd.DataFrame(xtest,columns=[ 'quantity_tons', 'customer', 'country', 'status',
       'item_type', 'application', 'thickness', 'width', 'product_ref',
        'selling_price', 'item_date_day', 'item_date_year',
       'item_date_month', 'delivery_date_day', 'delivery_date_month',
       'delivery_date_year',])

ypred = model.predict(xtest)


score = r2_score(ytest,ypred)
score
# Out:
# C:\Users\DINESH KUMAR\anaconda3\lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# 0.9952367740404259

# %% [markdown]
# ```
# # Note : Now time to find delivery date for wrong_delivery_date_df
# ```

# %%
dates_predict = wrong_delivery_dates_df[[ 'quantity_tons', 'customer', 'country', 'status',
       'item_type', 'application', 'thickness', 'width', 'product_ref',
        'selling_price', 'item_date_day', 'item_date_year',
       'item_date_month', 'delivery_date_day', 'delivery_date_month',
       'delivery_date_year',]]

# %%
dates_predict
# Out:
#         quantity_tons  customer  country  status  item_type  application  \
# 1            6.643822  30202938     25.0       1        5.0     3.713572
# 2            5.956169  30153963     30.0       1        6.0     3.332205
# 3            5.310301  30349574     32.0       1        3.0     4.077537
# 4            6.666354  30211560     28.0       1        5.0     2.302585
# 5            5.419608  30202938     25.0       1        5.0     3.713572
# ...               ...       ...      ...     ...        ...          ...
# 181668       4.629691  30200854     25.0       1        5.0     3.713572
# 181669       5.337954  30200854     25.0       1        5.0     3.713572
# 181670       1.443523  30200854     25.0       1        5.0     3.713572
# 181671      -0.323075  30200854     25.0       1        5.0     3.713572
# 181672       6.008043  30200854     25.0       1        5.0     3.713572
#
#         thickness     width product_ref  selling_price  item_date_day  \
# 1       -0.223144  7.098376  1668701718       6.953684              1
# 2       -0.967584  6.858565      628377       6.468211              1
# 3        0.832909  7.183112  1668701718       6.643790              1
# 4        1.386294  7.600902      640665       6.357842              1
# 5        0.405465  7.142827  1668701718       6.890609              1
# ...           ...       ...         ...            ...            ...
# 181668  -0.040822  7.106606   164141591       6.381816              2
# 181669  -0.051293  7.313220   164141591       6.378426              2
# 181670  -0.342490  7.130899   164141591       6.428105              2
# 181671  -0.162519  7.130899   164141591       6.398595              2
# 181672  -0.342490  7.122867   164141591       6.408529              2
#
#         item_date_year  item_date_month  delivery_date_day  \
# 1                 2021                4                  1
# 2                 2021                4                  1
# 3                 2021                4                  1
# 4                 2021                4                  1
# 5                 2021                4                  1
# ...                ...              ...                ...
# 181668            2020                7                  1
# 181669            2020                7                  1
# 181670            2020                7                  1
# 181671            2020                7                  1
# 181672            2020                7                  1
#
#         delivery_date_month  delivery_date_year
# 1                         4                2021
# 2                         1                2021
# 3                         1                2021
# 4                         3                2021
# 5                         4                2021
# ...                     ...                 ...
# 181668                    7                2020
# 181669                    7                2020
# 181670                    7                2020
# 181671                    7                2020
# 181672                    7                2020
#
# [16567 rows x 16 columns]

# %%
yhat_dates = model.predict(dates_predict)
# Out:
# C:\Users\DINESH KUMAR\anaconda3\lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(

# %%
yhat_dates  # We found correct dates for the wrong_delivery_dates_df
# Out:
# array([ 31.  , 156.96, 177.78, ...,  30.  ,  30.  ,  30.  ])

# %%
wrong_delivery_dates_df.drop('delivery_item_date_difference_num',axis=1,inplace=True)

wrong_delivery_dates_df['delivery_item_date_difference_num'] = yhat_dates

# wrong_delivery_dates_df.drop('delivery_item_date_difference',axis=1,inplace=True)
# Out:
# C:\Users\DINESH KUMAR\AppData\Local\Temp\ipykernel_15364\1257841389.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wrong_delivery_dates_df.drop('delivery_item_date_difference_num',axis=1,inplace=True)
# C:\Users\DINESH KUMAR\AppData\Local\Temp\ipykernel_15364\1257841389.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wrong_delivery_dates_df['delivery_item_date_difference_num'] = yhat_dates

# %%
wrong_delivery_dates_df['delivery_item_date_difference_num'] = wrong_delivery_dates_df['delivery_item_date_difference_num'].apply(lambda x : int(x))
# Out:
# C:\Users\DINESH KUMAR\AppData\Local\Temp\ipykernel_15364\778405921.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wrong_delivery_dates_df['delivery_item_date_difference_num'] = wrong_delivery_dates_df['delivery_item_date_difference_num'].apply(lambda x : int(x))

# %%
wrong_delivery_dates_df
# Out:
#         item_date  quantity_tons  customer  country  status  item_type  \
# 1      2021-04-01       6.643822  30202938     25.0       1        5.0
# 2      2021-04-01       5.956169  30153963     30.0       1        6.0
# 3      2021-04-01       5.310301  30349574     32.0       1        3.0
# 4      2021-04-01       6.666354  30211560     28.0       1        5.0
# 5      2021-04-01       5.419608  30202938     25.0       1        5.0
# ...           ...            ...       ...      ...     ...        ...
# 181668 2020-07-02       4.629691  30200854     25.0       1        5.0
# 181669 2020-07-02       5.337954  30200854     25.0       1        5.0
# 181670 2020-07-02       1.443523  30200854     25.0       1        5.0
# 181671 2020-07-02      -0.323075  30200854     25.0       1        5.0
# 181672 2020-07-02       6.008043  30200854     25.0       1        5.0
#
#         application  thickness     width product_ref delivery_date  \
# 1          3.713572  -0.223144  7.098376  1668701718    2021-04-01
# 2          3.332205  -0.967584  6.858565      628377    2021-01-01
# 3          4.077537   0.832909  7.183112  1668701718    2021-01-01
# 4          2.302585   1.386294  7.600902      640665    2021-03-01
# 5          3.713572   0.405465  7.142827  1668701718    2021-04-01
# ...             ...        ...       ...         ...           ...
# 181668     3.713572  -0.040822  7.106606   164141591    2020-07-01
# 181669     3.713572  -0.051293  7.313220   164141591    2020-07-01
# 181670     3.713572  -0.342490  7.130899   164141591    2020-07-01
# 181671     3.713572  -0.162519  7.130899   164141591    2020-07-01
# 181672     3.713572  -0.342490  7.122867   164141591    2020-07-01
#
#         selling_price  item_date_day  item_date_year  item_date_month  \
# 1            6.953684              1            2021                4
# 2            6.468211              1            2021                4
# 3            6.643790              1            2021                4
# 4            6.357842              1            2021                4
# 5            6.890609              1            2021                4
# ...               ...            ...             ...              ...
# 181668       6.381816              2            2020                7
# 181669       6.378426              2            2020                7
# 181670       6.428105              2            2020                7
# 181671       6.398595              2            2020                7
# 181672       6.408529              2            2020                7
#
#         delivery_date_day  delivery_date_month  delivery_date_year  \
# 1                       1                    4                2021
# 2                       1                    1                2021
# 3                       1                    1                2021
# 4                       1                    3                2021
# 5                       1                    4                2021
# ...                   ...                  ...                 ...
# 181668                  1                    7                2020
# 181669                  1                    7                2020
# 181670                  1                    7                2020
# 181671                  1                    7                2020
# 181672                  1                    7                2020
#
#         delivery_item_date_difference_num
# 1                                      31
# 2                                     156
# 3                                     177
# 4                                      31
# 5                                      31
# ...                                   ...
# 181668                                 30
# 181669                                 30
# 181670                                 30
# 181671                                 30
# 181672                                 30
#
# [16567 rows x 19 columns]

# %%
# correct_delivery_dates_df.drop('delivery_item_date_difference',axis=1,inplace=True)

correct_delivery_dates_df
# Out:
#         item_date  quantity_tons  customer  country  status  item_type  \
# 0      2021-04-01       3.991779  30156308     28.0       1        5.0
# 6      2021-04-01       1.259203  30209509     30.0       2        5.0
# 8      2021-04-01       4.235147  30341428     38.0       1        3.0
# 10     2021-04-01       2.216566  30209509     30.0       2        5.0
# 12     2021-04-01       3.314642  30165529     78.0       1        5.0
# ...           ...            ...       ...      ...     ...        ...
# 181433 2020-07-02       3.472467  30227718     25.0       0        3.0
# 181525 2020-07-02       4.196171  30161559     30.0       0        3.0
# 181527 2020-07-02       4.156686  30161559     30.0       0        3.0
# 181529 2020-07-02       4.025862  30161559     30.0       0        3.0
# 181531 2020-07-02       5.328963  30161559     30.0       0        3.0
#
#         application  thickness     width product_ref delivery_date  \
# 0          2.302585   0.693147  7.313220  1670798778    2021-07-01
# 6          3.713572  -0.967584  7.025538      611993    2021-07-01
# 8          2.302585  -0.510826  7.150701  1668701376    2021-07-01
# 10         3.713572  -0.967584  7.025538      611993    2021-07-01
# 12         2.302585  -0.287682  7.130899   164141591    2021-07-01
# ...             ...        ...       ...         ...           ...
# 181433     2.708050   1.791759  7.600902      640665    2020-08-01
# 181525     2.302585   1.348073  7.329750      640665    2020-08-01
# 181527     2.302585   1.766442  7.329750      640665    2020-08-01
# 181529     2.302585   2.060514  7.313220      640665    2020-08-01
# 181531     2.302585   1.348073  7.512071      640665    2020-08-01
#
#         selling_price  item_date_day  item_date_year  item_date_month  \
# 0            6.749931              1            2021                4
# 6            5.975038              1            2021                4
# 8            7.217443              1            2021                4
# 10           5.975038              1            2021                4
# 12           7.001246              1            2021                4
# ...               ...            ...             ...              ...
# 181433       6.313548              2            2020                7
# 181525       6.126869              2            2020                7
# 181527       6.124683              2            2020                7
# 181529       6.126869              2            2020                7
# 181531       6.131226              2            2020                7
#
#         delivery_date_day  delivery_date_month  delivery_date_year  \
# 0                       1                    7                2021
# 6                       1                    7                2021
# 8                       1                    7                2021
# 10                      1                    7                2021
# 12                      1                    7                2021
# ...                   ...                  ...                 ...
# 181433                  1                    8                2020
# 181525                  1                    8                2020
# 181527                  1                    8                2020
# 181529                  1                    8                2020
# 181531                  1                    8                2020
#
#         delivery_item_date_difference_num
# 0                                      91
# 6                                      91
# 8                                      91
# 10                                     91
# 12                                     91
# ...                                   ...
# 181433                                 30
# 181525                                 30
# 181527                                 30
# 181529                                 30
# 181531                                 30
#
# [165073 rows x 19 columns]

# %%
cleaned_data = pd.concat([correct_delivery_dates_df,wrong_delivery_dates_df],axis=0,ignore_index=True)

# %%
cleaned_data
# Out:
#         item_date  quantity_tons  customer  country  status  item_type  \
# 0      2021-04-01       3.991779  30156308     28.0       1        5.0
# 1      2021-04-01       1.259203  30209509     30.0       2        5.0
# 2      2021-04-01       4.235147  30341428     38.0       1        3.0
# 3      2021-04-01       2.216566  30209509     30.0       2        5.0
# 4      2021-04-01       3.314642  30165529     78.0       1        5.0
# ...           ...            ...       ...      ...     ...        ...
# 181635 2020-07-02       4.629691  30200854     25.0       1        5.0
# 181636 2020-07-02       5.337954  30200854     25.0       1        5.0
# 181637 2020-07-02       1.443523  30200854     25.0       1        5.0
# 181638 2020-07-02      -0.323075  30200854     25.0       1        5.0
# 181639 2020-07-02       6.008043  30200854     25.0       1        5.0
#
#         application  thickness     width product_ref delivery_date  \
# 0          2.302585   0.693147  7.313220  1670798778    2021-07-01
# 1          3.713572  -0.967584  7.025538      611993    2021-07-01
# 2          2.302585  -0.510826  7.150701  1668701376    2021-07-01
# 3          3.713572  -0.967584  7.025538      611993    2021-07-01
# 4          2.302585  -0.287682  7.130899   164141591    2021-07-01
# ...             ...        ...       ...         ...           ...
# 181635     3.713572  -0.040822  7.106606   164141591    2020-07-01
# 181636     3.713572  -0.051293  7.313220   164141591    2020-07-01
# 181637     3.713572  -0.342490  7.130899   164141591    2020-07-01
# 181638     3.713572  -0.162519  7.130899   164141591    2020-07-01
# 181639     3.713572  -0.342490  7.122867   164141591    2020-07-01
#
#         selling_price  item_date_day  item_date_year  item_date_month  \
# 0            6.749931              1            2021                4
# 1            5.975038              1            2021                4
# 2            7.217443              1            2021                4
# 3            5.975038              1            2021                4
# 4            7.001246              1            2021                4
# ...               ...            ...             ...              ...
# 181635       6.381816              2            2020                7
# 181636       6.378426              2            2020                7
# 181637       6.428105              2            2020                7
# 181638       6.398595              2            2020                7
# 181639       6.408529              2            2020                7
#
#         delivery_date_day  delivery_date_month  delivery_date_year  \
# 0                       1                    7                2021
# 1                       1                    7                2021
# 2                       1                    7                2021
# 3                       1                    7                2021
# 4                       1                    7                2021
# ...                   ...                  ...                 ...
# 181635                  1                    7                2020
# 181636                  1                    7                2020
# 181637                  1                    7                2020
# 181638                  1                    7                2020
# 181639                  1                    7                2020
#
#         delivery_item_date_difference_num
# 0                                      91
# 1                                      91
# 2                                      91
# 3                                      91
# 4                                      91
# ...                                   ...
# 181635                                 30
# 181636                                 30
# 181637                                 30
# 181638                                 30
# 181639                                 30
#
# [181640 rows x 19 columns]

# %%
cleaned_data.columns
# Out:
# Index(['item_date', 'quantity_tons', 'customer', 'country', 'status',
#        'item_type', 'application', 'thickness', 'width', 'product_ref',
#        'delivery_date', 'selling_price', 'item_date_day', 'item_date_year',
#        'item_date_month', 'delivery_date_day', 'delivery_date_month',
#        'delivery_date_year', 'delivery_item_date_difference_num'],
#       dtype='object')

# %%
cleaned_data.dtypes
# Out:
# item_date                            datetime64[ns]
# quantity_tons                               float64
# customer                                     object
# country                                     float64
# status                                        int64
# item_type                                   float64
# application                                 float64
# thickness                                   float64
# width                                       float64
# product_ref                                  object
# delivery_date                        datetime64[ns]
# selling_price                               float64
# item_date_day                                 int64
# item_date_year                                int64
# item_date_month                               int64
# delivery_date_day                             int64
# delivery_date_month                           int64
# delivery_date_year                            int64
# delivery_item_date_difference_num             int64
# dtype: object

# %%
cleaned_data
# Out:
#         item_date  quantity_tons  customer  country  status  item_type  \
# 0      2021-04-01       3.991779  30156308     28.0       1        5.0
# 1      2021-04-01       1.259203  30209509     30.0       2        5.0
# 2      2021-04-01       4.235147  30341428     38.0       1        3.0
# 3      2021-04-01       2.216566  30209509     30.0       2        5.0
# 4      2021-04-01       3.314642  30165529     78.0       1        5.0
# ...           ...            ...       ...      ...     ...        ...
# 181635 2020-07-02       4.629691  30200854     25.0       1        5.0
# 181636 2020-07-02       5.337954  30200854     25.0       1        5.0
# 181637 2020-07-02       1.443523  30200854     25.0       1        5.0
# 181638 2020-07-02      -0.323075  30200854     25.0       1        5.0
# 181639 2020-07-02       6.008043  30200854     25.0       1        5.0
#
#         application  thickness     width product_ref delivery_date  \
# 0          2.302585   0.693147  7.313220  1670798778    2021-07-01
# 1          3.713572  -0.967584  7.025538      611993    2021-07-01
# 2          2.302585  -0.510826  7.150701  1668701376    2021-07-01
# 3          3.713572  -0.967584  7.025538      611993    2021-07-01
# 4          2.302585  -0.287682  7.130899   164141591    2021-07-01
# ...             ...        ...       ...         ...           ...
# 181635     3.713572  -0.040822  7.106606   164141591    2020-07-01
# 181636     3.713572  -0.051293  7.313220   164141591    2020-07-01
# 181637     3.713572  -0.342490  7.130899   164141591    2020-07-01
# 181638     3.713572  -0.162519  7.130899   164141591    2020-07-01
# 181639     3.713572  -0.342490  7.122867   164141591    2020-07-01
#
#         selling_price  item_date_day  item_date_year  item_date_month  \
# 0            6.749931              1            2021                4
# 1            5.975038              1            2021                4
# 2            7.217443              1            2021                4
# 3            5.975038              1            2021                4
# 4            7.001246              1            2021                4
# ...               ...            ...             ...              ...
# 181635       6.381816              2            2020                7
# 181636       6.378426              2            2020                7
# 181637       6.428105              2            2020                7
# 181638       6.398595              2            2020                7
# 181639       6.408529              2            2020                7
#
#         delivery_date_day  delivery_date_month  delivery_date_year  \
# 0                       1                    7                2021
# 1                       1                    7                2021
# 2                       1                    7                2021
# 3                       1                    7                2021
# 4                       1                    7                2021
# ...                   ...                  ...                 ...
# 181635                  1                    7                2020
# 181636                  1                    7                2020
# 181637                  1                    7                2020
# 181638                  1                    7                2020
# 181639                  1                    7                2020
#
#         delivery_item_date_difference_num
# 0                                      91
# 1                                      91
# 2                                      91
# 3                                      91
# 4                                      91
# ...                                   ...
# 181635                                 30
# 181636                                 30
# 181637                                 30
# 181638                                 30
# 181639                                 30
#
# [181640 rows x 19 columns]

# %%
cleaned_data.columns
# Out:
# Index(['item_date', 'quantity_tons', 'customer', 'country', 'status',
#        'item_type', 'application', 'thickness', 'width', 'product_ref',
#        'delivery_date', 'selling_price', 'item_date_day', 'item_date_year',
#        'item_date_month', 'delivery_date_day', 'delivery_date_month',
#        'delivery_date_year', 'delivery_item_date_difference_num'],
#       dtype='object')

# %%
def delivery_date(date,days_x):

  delivery_date = []

  for i,j in zip(date,days_x):

      result_date = i + pd.DateOffset(days=j)

      result_date_str = result_date.strftime('%Y-%m-%d')

      delivery_date.append(result_date_str)
  return delivery_date

# %%
x = delivery_date(cleaned_data['item_date'],cleaned_data['delivery_item_date_difference_num'])
x
# Out:
# ['2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-06-01',
#  '2021-07-01',
#  '2021-06-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-06-01',
#  '2021-05-01',
#  '2021-07-01',
#  '2021-06-01',
#  '2021-05-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-05-01',
#  '2023-01-01',
#  '2021-08-01',
#  '2021-05-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-05-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-05-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-05-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-06-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-09-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-09-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-08-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-08-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-10-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-08-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-09-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-08-01',
#  '2021-10-01',
#  '2021-08-01',
#  '2021-08-01',
#  '2021-08-01',
#  '2021-08-01',
#  '2021-08-01',
#  '2021-08-01',
#  '2021-08-01',
#  '2021-08-01',
#  '2021-08-01',
#  '2021-08-01',
#  '2021-08-01',
#  '2021-08-01',
#  '2021-08-01',
#  '2021-05-01',
#  '2021-08-01',
#  '2021-05-01',
#  '2021-08-01',
#  '2021-05-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-08-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-08-01',
#  '2021-08-01',
#  '2021-08-01',
#  '2021-08-01',
#  '2021-08-01',
#  '2021-08-01',
#  '2021-08-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-05-01',
#  '2021-08-01',
#  '2021-08-01',
#  '2021-08-01',
#  '2021-08-01',
#  '2021-08-01',
#  '2021-11-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-10-01',
#  '2021-10-01',
#  '2021-10-01',
#  '2021-10-01',
#  '2021-10-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-06-01',
#  '2021-05-01',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-05-01',
#  '2021-10-01',
#  '2021-10-01',
#  '2021-10-01',
#  '2021-10-01',
#  '2021-10-01',
#  '2021-10-01',
#  '2021-10-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-04-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-04-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-05-01',
#  '2021-07-01',
#  '2021-05-01',
#  '2021-05-01',
#  '2021-05-01',
#  '2021-07-01',
#  '2021-05-01',
#  '2021-05-01',
#  '2021-05-01',
#  '2021-06-01',
#  '2021-05-01',
#  '2021-05-01',
#  '2021-05-01',
#  '2021-06-01',
#  '2021-05-01',
#  '2021-05-01',
#  '2021-05-01',
#  '2021-06-01',
#  '2021-05-01',
#  '2021-05-01',
#  '2021-05-01',
#  '2021-06-01',
#  '2021-05-01',
#  '2021-05-01',
#  '2021-05-01',
#  '2021-06-01',
#  '2021-05-01',
#  '2021-06-01',
#  '2021-05-01',
#  '2021-06-01',
#  '2021-05-01',
#  '2021-06-01',
#  '2021-05-01',
#  '2021-06-01',
#  '2021-05-01',
#  '2021-06-01',
#  '2021-05-01',
#  '2021-06-01',
#  '2021-07-01',
#  '2021-06-01',
#  '2021-07-01',
#  '2021-06-01',
#  '2021-07-01',
#  '2021-04-01',
#  '2021-07-01',
#  '2021-04-01',
#  '2021-07-01',
#  '2021-04-01',
#  '2021-07-01',
#  '2021-04-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-04-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-04-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-04-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-04-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-04-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-04-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-04-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-04-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-04-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-04-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-04-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-04-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-04-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-04-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-04-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-04-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-04-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-04-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-06-01',
#  '2021-07-01',
#  '2021-04-01',
#  '2021-08-01',
#  '2021-04-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-10-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-04-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-11-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-04-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-04-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-04-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-04-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-04-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-04-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-04-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-04-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-04-01',
#  '2021-09-01',
#  '2021-06-01',
#  '2021-09-01',
#  '2021-04-01',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-09-01',
#  '2021-04-01',
#  '2021-09-01',
#  '2021-10-01',
#  '2021-09-01',
#  '2021-06-01',
#  '2021-09-01',
#  '2021-10-01',
#  '2021-09-01',
#  '2021-06-01',
#  '2021-09-01',
#  '2021-10-01',
#  '2021-09-01',
#  '2021-06-01',
#  '2021-09-01',
#  '2021-10-01',
#  '2021-09-01',
#  '2021-06-01',
#  '2021-09-01',
#  '2021-10-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-09-01',
#  '2021-04-01',
#  '2021-09-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-04-01',
#  '2021-08-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-04-01',
#  '2021-07-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-04-01',
#  '2021-10-01',
#  '2021-07-01',
#  '2021-10-01',
#  '2021-04-01',
#  '2021-06-01',
#  '2021-07-01',
#  '2021-05-01',
#  '2021-04-01',
#  '2021-05-01',
#  '2021-07-01',
#  '2021-05-01',
#  '2021-04-01',
#  '2021-05-01',
#  '2021-07-01',
#  '2021-05-01',
#  '2021-04-01',
#  '2021-05-01',
#  '2021-10-01',
#  '2021-05-01',
#  '2021-07-01',
#  '2021-05-01',
#  '2021-10-01',
#  '2021-09-01',
#  '2021-06-01',
#  '2021-09-01',
#  '2021-10-01',
#  '2021-09-01',
#  '2021-10-01',
#  '2021-09-01',
#  '2021-10-01',
#  '2021-09-01',
#  '2021-10-01',
#  '2021-09-01',
#  '2021-10-01',
#  ...]

# %%
cleaned_data['delivery_date_pred'] = x

# %%
cleaned_data
# Out:
#         item_date  quantity_tons  customer  country  status  item_type  \
# 0      2021-04-01       3.991779  30156308     28.0       1        5.0
# 1      2021-04-01       1.259203  30209509     30.0       2        5.0
# 2      2021-04-01       4.235147  30341428     38.0       1        3.0
# 3      2021-04-01       2.216566  30209509     30.0       2        5.0
# 4      2021-04-01       3.314642  30165529     78.0       1        5.0
# ...           ...            ...       ...      ...     ...        ...
# 181635 2020-07-02       4.629691  30200854     25.0       1        5.0
# 181636 2020-07-02       5.337954  30200854     25.0       1        5.0
# 181637 2020-07-02       1.443523  30200854     25.0       1        5.0
# 181638 2020-07-02      -0.323075  30200854     25.0       1        5.0
# 181639 2020-07-02       6.008043  30200854     25.0       1        5.0
#
#         application  thickness     width product_ref delivery_date  \
# 0          2.302585   0.693147  7.313220  1670798778    2021-07-01
# 1          3.713572  -0.967584  7.025538      611993    2021-07-01
# 2          2.302585  -0.510826  7.150701  1668701376    2021-07-01
# 3          3.713572  -0.967584  7.025538      611993    2021-07-01
# 4          2.302585  -0.287682  7.130899   164141591    2021-07-01
# ...             ...        ...       ...         ...           ...
# 181635     3.713572  -0.040822  7.106606   164141591    2020-07-01
# 181636     3.713572  -0.051293  7.313220   164141591    2020-07-01
# 181637     3.713572  -0.342490  7.130899   164141591    2020-07-01
# 181638     3.713572  -0.162519  7.130899   164141591    2020-07-01
# 181639     3.713572  -0.342490  7.122867   164141591    2020-07-01
#
#         selling_price  item_date_day  item_date_year  item_date_month  \
# 0            6.749931              1            2021                4
# 1            5.975038              1            2021                4
# 2            7.217443              1            2021                4
# 3            5.975038              1            2021                4
# 4            7.001246              1            2021                4
# ...               ...            ...             ...              ...
# 181635       6.381816              2            2020                7
# 181636       6.378426              2            2020                7
# 181637       6.428105              2            2020                7
# 181638       6.398595              2            2020                7
# 181639       6.408529              2            2020                7
#
#         delivery_date_day  delivery_date_month  delivery_date_year  \
# 0                       1                    7                2021
# 1                       1                    7                2021
# 2                       1                    7                2021
# 3                       1                    7                2021
# 4                       1                    7                2021
# ...                   ...                  ...                 ...
# 181635                  1                    7                2020
# 181636                  1                    7                2020
# 181637                  1                    7                2020
# 181638                  1                    7                2020
# 181639                  1                    7                2020
#
#         delivery_item_date_difference_num delivery_date_pred
# 0                                      91         2021-07-01
# 1                                      91         2021-07-01
# 2                                      91         2021-07-01
# 3                                      91         2021-07-01
# 4                                      91         2021-07-01
# ...                                   ...                ...
# 181635                                 30         2020-08-01
# 181636                                 30         2020-08-01
# 181637                                 30         2020-08-01
# 181638                                 30         2020-08-01
# 181639                                 30         2020-08-01
#
# [181640 rows x 20 columns]

# %%
cleaned_data.columns
# Out:
# Index(['item_date', 'quantity_tons', 'customer', 'country', 'status',
#        'item_type', 'application', 'thickness', 'width', 'product_ref',
#        'delivery_date', 'selling_price', 'item_date_day', 'item_date_year',
#        'item_date_month', 'delivery_date_day', 'delivery_date_month',
#        'delivery_date_year', 'delivery_item_date_difference_num',
#        'delivery_date_pred'],
#       dtype='object')

# %%
cleaned_data = cleaned_data[[ 'quantity_tons', 'customer', 'country', 'status',
       'item_type', 'application', 'thickness', 'width', 'product_ref'
       , 'selling_price', 'item_date_day', 'item_date_year',
       'item_date_month','item_date',
       'delivery_date_pred']]

# %%
cleaned_data['delivery_date_pred'] = pd.to_datetime(cleaned_data['delivery_date_pred'])
# Out:
# C:\Users\DINESH KUMAR\AppData\Local\Temp\ipykernel_15364\815200478.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_data['delivery_date_pred'] = pd.to_datetime(cleaned_data['delivery_date_pred'])

# %%
cleaned_data['delivery_date_day'] = cleaned_data['delivery_date_pred'].dt.day
cleaned_data['delivery_date_month'] = cleaned_data['delivery_date_pred'].dt.month
cleaned_data['delivery_date_year'] = cleaned_data['delivery_date_pred'].dt.year
# Out:
# C:\Users\DINESH KUMAR\AppData\Local\Temp\ipykernel_15364\120759387.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_data['delivery_date_day'] = cleaned_data['delivery_date_pred'].dt.day
# C:\Users\DINESH KUMAR\AppData\Local\Temp\ipykernel_15364\120759387.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_data['delivery_date_month'] = cleaned_data['delivery_date_pred'].dt.month
# C:\Users\DINESH KUMAR\AppData\Local\Temp\ipykernel_15364\120759387.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_data['delivery_date_year'] = cleaned_data['delivery_date_pred'].dt.year

# %%
cleaned_data.dtypes
# Out:
# quantity_tons                 float64
# customer                       object
# country                       float64
# status                          int64
# item_type                     float64
# application                   float64
# thickness                     float64
# width                         float64
# product_ref                    object
# selling_price                 float64
# item_date_day                   int64
# item_date_year                  int64
# item_date_month                 int64
# item_date              datetime64[ns]
# delivery_date_pred     datetime64[ns]
# delivery_date_day               int64
# delivery_date_month             int64
# delivery_date_year              int64
# dtype: object

# %%
cleaned_data
# Out:
#         quantity_tons  customer  country  status  item_type  application  \
# 0            3.991779  30156308     28.0       1        5.0     2.302585
# 1            1.259203  30209509     30.0       2        5.0     3.713572
# 2            4.235147  30341428     38.0       1        3.0     2.302585
# 3            2.216566  30209509     30.0       2        5.0     3.713572
# 4            3.314642  30165529     78.0       1        5.0     2.302585
# ...               ...       ...      ...     ...        ...          ...
# 181635       4.629691  30200854     25.0       1        5.0     3.713572
# 181636       5.337954  30200854     25.0       1        5.0     3.713572
# 181637       1.443523  30200854     25.0       1        5.0     3.713572
# 181638      -0.323075  30200854     25.0       1        5.0     3.713572
# 181639       6.008043  30200854     25.0       1        5.0     3.713572
#
#         thickness     width product_ref  selling_price  item_date_day  \
# 0        0.693147  7.313220  1670798778       6.749931              1
# 1       -0.967584  7.025538      611993       5.975038              1
# 2       -0.510826  7.150701  1668701376       7.217443              1
# 3       -0.967584  7.025538      611993       5.975038              1
# 4       -0.287682  7.130899   164141591       7.001246              1
# ...           ...       ...         ...            ...            ...
# 181635  -0.040822  7.106606   164141591       6.381816              2
# 181636  -0.051293  7.313220   164141591       6.378426              2
# 181637  -0.342490  7.130899   164141591       6.428105              2
# 181638  -0.162519  7.130899   164141591       6.398595              2
# 181639  -0.342490  7.122867   164141591       6.408529              2
#
#         item_date_year  item_date_month  item_date delivery_date_pred  \
# 0                 2021                4 2021-04-01         2021-07-01
# 1                 2021                4 2021-04-01         2021-07-01
# 2                 2021                4 2021-04-01         2021-07-01
# 3                 2021                4 2021-04-01         2021-07-01
# 4                 2021                4 2021-04-01         2021-07-01
# ...                ...              ...        ...                ...
# 181635            2020                7 2020-07-02         2020-08-01
# 181636            2020                7 2020-07-02         2020-08-01
# 181637            2020                7 2020-07-02         2020-08-01
# 181638            2020                7 2020-07-02         2020-08-01
# 181639            2020                7 2020-07-02         2020-08-01
#
#         delivery_date_day  delivery_date_month  delivery_date_year
# 0                       1                    7                2021
# 1                       1                    7                2021
# 2                       1                    7                2021
# 3                       1                    7                2021
# 4                       1                    7                2021
# ...                   ...                  ...                 ...
# 181635                  1                    8                2020
# 181636                  1                    8                2020
# 181637                  1                    8                2020
# 181638                  1                    8                2020
# 181639                  1                    8                2020
#
# [181640 rows x 18 columns]

# %%
cleaned_data.isnull().sum()
# Out:
# quantity_tons          0
# customer               0
# country                0
# status                 0
# item_type              0
# application            0
# thickness              0
# width                  0
# product_ref            0
# selling_price          0
# item_date_day          0
# item_date_year         0
# item_date_month        0
# item_date              0
# delivery_date_pred     0
# delivery_date_day      0
# delivery_date_month    0
# delivery_date_year     0
# dtype: int64

# %%
cleaned_data = cleaned_data.dropna()

# %%
cleaned_data['customer'] = pd.to_numeric(cleaned_data['customer'],errors='coerce').fillna(method='bfill').astype(int)

# %%
cleaned_data['customer'] = cleaned_data['customer'].apply(lambda x : int(x))

# %%
cleaned_data.columns
# Out:
# Index(['quantity_tons', 'customer', 'country', 'status', 'item_type',
#        'application', 'thickness', 'width', 'product_ref', 'selling_price',
#        'item_date_day', 'item_date_year', 'item_date_month', 'item_date',
#        'delivery_date_pred', 'delivery_date_day', 'delivery_date_month',
#        'delivery_date_year'],
#       dtype='object')

# %%
cleaned_data = cleaned_data[['quantity_tons', 'customer', 'country', 'status', 'item_type',
       'application', 'thickness', 'width', 'product_ref', 'selling_price','item_date', 'delivery_date_pred',
       'item_date_day', 'item_date_month',  'item_date_year',
       'delivery_date_day', 'delivery_date_month',
       'delivery_date_year']]

# %%
cleaned_data
# Out:
#         quantity_tons  customer  country  status  item_type  application  \
# 0            3.991779  30156308     28.0       1        5.0     2.302585
# 1            1.259203  30209509     30.0       2        5.0     3.713572
# 2            4.235147  30341428     38.0       1        3.0     2.302585
# 3            2.216566  30209509     30.0       2        5.0     3.713572
# 4            3.314642  30165529     78.0       1        5.0     2.302585
# ...               ...       ...      ...     ...        ...          ...
# 181635       4.629691  30200854     25.0       1        5.0     3.713572
# 181636       5.337954  30200854     25.0       1        5.0     3.713572
# 181637       1.443523  30200854     25.0       1        5.0     3.713572
# 181638      -0.323075  30200854     25.0       1        5.0     3.713572
# 181639       6.008043  30200854     25.0       1        5.0     3.713572
#
#         thickness     width product_ref  selling_price  item_date  \
# 0        0.693147  7.313220  1670798778       6.749931 2021-04-01
# 1       -0.967584  7.025538      611993       5.975038 2021-04-01
# 2       -0.510826  7.150701  1668701376       7.217443 2021-04-01
# 3       -0.967584  7.025538      611993       5.975038 2021-04-01
# 4       -0.287682  7.130899   164141591       7.001246 2021-04-01
# ...           ...       ...         ...            ...        ...
# 181635  -0.040822  7.106606   164141591       6.381816 2020-07-02
# 181636  -0.051293  7.313220   164141591       6.378426 2020-07-02
# 181637  -0.342490  7.130899   164141591       6.428105 2020-07-02
# 181638  -0.162519  7.130899   164141591       6.398595 2020-07-02
# 181639  -0.342490  7.122867   164141591       6.408529 2020-07-02
#
#        delivery_date_pred  item_date_day  item_date_month  item_date_year  \
# 0              2021-07-01              1                4            2021
# 1              2021-07-01              1                4            2021
# 2              2021-07-01              1                4            2021
# 3              2021-07-01              1                4            2021
# 4              2021-07-01              1                4            2021
# ...                   ...            ...              ...             ...
# 181635         2020-08-01              2                7            2020
# 181636         2020-08-01              2                7            2020
# 181637         2020-08-01              2                7            2020
# 181638         2020-08-01              2                7            2020
# 181639         2020-08-01              2                7            2020
#
#         delivery_date_day  delivery_date_month  delivery_date_year
# 0                       1                    7                2021
# 1                       1                    7                2021
# 2                       1                    7                2021
# 3                       1                    7                2021
# 4                       1                    7                2021
# ...                   ...                  ...                 ...
# 181635                  1                    8                2020
# 181636                  1                    8                2020
# 181637                  1                    8                2020
# 181638                  1                    8                2020
# 181639                  1                    8                2020
#
# [181640 rows x 18 columns]

# %%
cleaned_data['product_ref'] = pd.to_numeric(cleaned_data['product_ref'] )

# %%
cleaned_data.dtypes
# Out:
# quantity_tons                 float64
# customer                        int64
# country                       float64
# status                          int64
# item_type                     float64
# application                   float64
# thickness                     float64
# width                         float64
# product_ref                     int64
# selling_price                 float64
# item_date              datetime64[ns]
# delivery_date_pred     datetime64[ns]
# item_date_day                   int64
# item_date_month                 int64
# item_date_year                  int64
# delivery_date_day               int64
# delivery_date_month             int64
# delivery_date_year              int64
# dtype: object

# %% [markdown]
# #**Cleaned Dataset**

# %% [markdown]
# ```
# # Here you can download the cleaned dataset
# ```

# %%
cleaned_data.to_csv('icm_final_cd.csv',index=False)

# %% [markdown]
# ```
#                                                          Finished
# ```
