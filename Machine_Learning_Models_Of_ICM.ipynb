# %% [markdown]
# # **Classification Model**

# %% [markdown]
# ```
# # Aim is to predict status either "WON" or "Lost"
# ```

# %% [markdown]
# **`Upgrade the version of sklearn`**

# %%
import sklearn
sklearn.__version__


# Don't forget customer id
# Out:
# '1.3.1'

# %%
pip install scikit-learn==1.3.1

# %% [markdown]
# ## **Required Library**

# %%
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn import metrics
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc , accuracy_score
import matplotlib.pyplot as plt
import pickle
import pandas as pd

# %% [markdown]
# ## **Data Collection**

# %%
df = pd.read_csv('/content/icm_final_cd.csv')

# %%
df
# Out:
#         quantity_tons  customer  country  status  item_type  application  \
# 0            3.991779  30156308     28.0       1        5.0     2.302585
# 1            1.259203  30209509     30.0       2        5.0     3.713572
# 2            4.235147  30341428     38.0       1        3.0     2.302585
# 3            2.216566  30209509     30.0       2        5.0     3.713572
# 4            3.314642  30165529     78.0       1        5.0     2.302585
# ...               ...       ...      ...     ...        ...          ...
# 181635       4.629691  30200854     25.0       1        5.0     3.713572
# 181636       5.337954  30200854     25.0       1        5.0     3.713572
# 181637       1.443523  30200854     25.0       1        5.0     3.713572
# 181638      -0.323075  30200854     25.0       1        5.0     3.713572
# 181639       6.008043  30200854     25.0       1        5.0     3.713572
#
#         thickness     width  product_ref  selling_price   item_date  \
# 0        0.693147  7.313220   1670798778       6.749931  2021-04-01
# 1       -0.967584  7.025538       611993       5.975038  2021-04-01
# 2       -0.510826  7.150701   1668701376       7.217443  2021-04-01
# 3       -0.967584  7.025538       611993       5.975038  2021-04-01
# 4       -0.287682  7.130899    164141591       7.001246  2021-04-01
# ...           ...       ...          ...            ...         ...
# 181635  -0.040822  7.106606    164141591       6.381816  2020-07-02
# 181636  -0.051293  7.313220    164141591       6.378426  2020-07-02
# 181637  -0.342490  7.130899    164141591       6.428105  2020-07-02
# 181638  -0.162519  7.130899    164141591       6.398595  2020-07-02
# 181639  -0.342490  7.122867    164141591       6.408529  2020-07-02
#
#        delivery_date_pred  item_date_day  item_date_month  item_date_year  \
# 0              2021-07-01              1                4            2021
# 1              2021-07-01              1                4            2021
# 2              2021-07-01              1                4            2021
# 3              2021-07-01              1                4            2021
# 4              2021-07-01              1                4            2021
# ...                   ...            ...              ...             ...
# 181635         2020-08-01              2                7            2020
# 181636         2020-08-01              2                7            2020
# 181637         2020-08-01              2                7            2020
# 181638         2020-08-01              2                7            2020
# 181639         2020-08-01              2                7            2020
#
#         delivery_date_day  delivery_date_month  delivery_date_year
# 0                       1                    7                2021
# 1                       1                    7                2021
# 2                       1                    7                2021
# 3                       1                    7                2021
# 4                       1                    7                2021
# ...                   ...                  ...                 ...
# 181635                  1                    8                2020
# 181636                  1                    8                2020
# 181637                  1                    8                2020
# 181638                  1                    8                2020
# 181639                  1                    8                2020
#
# [181640 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181640 entries, 0 to 181639
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   quantity_tons        181640 non-null  float64
#  1   country              181640 non-null  int64
#  2   item_type            181640 non-null  int64
#  3   application          181640 non-null  float64
#  4   thickness            181640 non-null  float64
#  5   width                181640 non-null  float64
#  6   product_ref          181640 non-null  int64
#  7   item_date            181640 non-null  object
#  8   item_date_day        181640 non-null  int64
#  9   item_date_year       181640 non-null  int64
#  10  item_date_month      181640 non-null  int64
#  11  delivery_date_pred   181640 non-null  object
#  12  delivery_date_days   181640 non-null  int64
#  13  delivery_date_month  181640 non-null  int64
#  14  delivery_date_year   181640 non-null  int64
#  15  selling_price        181640 non-null  float64
#  16  status               181640 non-null  int64
# dtypes: float64(5), int64(10), object(2)
# memory usage: 23.6+ MB

# %%
df['status'].value_counts()
# Out:
# 1    116009
# 0     34433
# 5     19568
# 7      4276
# 3      4169
# 2      3121
# 8        53
# 4        10
# 6         1
# Name: status, dtype: int64

# %%
df.columns
# Out:
# Index(['quantity_tons', 'customer', 'country', 'status', 'item_type',
#        'application', 'thickness', 'width', 'product_ref', 'selling_price',
#        'item_date', 'delivery_date_pred', 'item_date_day', 'item_date_month',
#        'item_date_year', 'delivery_date_day', 'delivery_date_month',
#        'delivery_date_year'],
#       dtype='object')

# %%
df = df[['quantity_tons', 'customer', 'country',  'item_type',
       'application', 'thickness', 'width', 'product_ref',
       'item_date_day', 'item_date_month',
       'item_date_year', 'delivery_date_day', 'delivery_date_month',
       'delivery_date_year','selling_price','status']]

# %%
df = df.query('status==1 or status ==0')

# %%
df
# Out:
#         quantity_tons  customer  country  item_type  application  thickness  \
# 0            3.991779  30156308     28.0        5.0     2.302585   0.693147
# 2            4.235147  30341428     38.0        3.0     2.302585  -0.510826
# 4            3.314642  30165529     78.0        5.0     2.302585  -0.287682
# 5            3.473063  30202362     27.0        3.0     2.302585  -0.510826
# 7            3.035295  30211222     30.0        5.0     2.302585  -0.798508
# ...               ...       ...      ...        ...          ...        ...
# 181635       4.629691  30200854     25.0        5.0     3.713572  -0.040822
# 181636       5.337954  30200854     25.0        5.0     3.713572  -0.051293
# 181637       1.443523  30200854     25.0        5.0     3.713572  -0.342490
# 181638      -0.323075  30200854     25.0        5.0     3.713572  -0.162519
# 181639       6.008043  30200854     25.0        5.0     3.713572  -0.342490
#
#            width  product_ref  item_date_day  item_date_month  item_date_year  \
# 0       7.313220   1670798778              1                4            2021
# 2       7.150701   1668701376              1                4            2021
# 4       7.130899    164141591              1                4            2021
# 5       6.917706       628377              1                4            2021
# 7       6.802395       611993              1                4            2021
# ...          ...          ...            ...              ...             ...
# 181635  7.106606    164141591              2                7            2020
# 181636  7.313220    164141591              2                7            2020
# 181637  7.130899    164141591              2                7            2020
# 181638  7.130899    164141591              2                7            2020
# 181639  7.122867    164141591              2                7            2020
#
#         delivery_date_day  delivery_date_month  delivery_date_year  \
# 0                       1                    7                2021
# 2                       1                    7                2021
# 4                       1                    7                2021
# 5                       1                    7                2021
# 7                       1                    7                2021
# ...                   ...                  ...                 ...
# 181635                  1                    8                2020
# 181636                  1                    8                2020
# 181637                  1                    8                2020
# 181638                  1                    8                2020
# 181639                  1                    8                2020
#
#         selling_price  status
# 0            6.749931       1
# 2            7.217443       1
# 4            7.001246       1
# 5            6.880384       1
# 7            7.181736       1
# ...               ...     ...
# 181635       6.381816       1
# 181636       6.378426       1
# 181637       6.428105       1
# 181638       6.398595       1
# 181639       6.408529       1
#
# [150442 rows x 16 columns]

# %% [markdown]
# ## **Unbalanced Data**

# %%
df.status.value_counts(normalize=True)*100
# Out:
# 1    77.11211
# 0    22.88789
# Name: status, dtype: float64

# %% [markdown]
# ```
# # In Our Data we 77% of Won datapoint and 22% of Lost data point , So In predict it will mislead
# ```

# %% [markdown]
# ## **Rectify Balanced Data -- Using Oversampling**

# %%
x = df.drop('status',axis=1)

y = df['status']

# %%
x
# Out:
#         quantity_tons  customer  country  item_type  application  thickness  \
# 0            3.991779  30156308     28.0        5.0     2.302585   0.693147
# 2            4.235147  30341428     38.0        3.0     2.302585  -0.510826
# 4            3.314642  30165529     78.0        5.0     2.302585  -0.287682
# 5            3.473063  30202362     27.0        3.0     2.302585  -0.510826
# 7            3.035295  30211222     30.0        5.0     2.302585  -0.798508
# ...               ...       ...      ...        ...          ...        ...
# 181635       4.629691  30200854     25.0        5.0     3.713572  -0.040822
# 181636       5.337954  30200854     25.0        5.0     3.713572  -0.051293
# 181637       1.443523  30200854     25.0        5.0     3.713572  -0.342490
# 181638      -0.323075  30200854     25.0        5.0     3.713572  -0.162519
# 181639       6.008043  30200854     25.0        5.0     3.713572  -0.342490
#
#            width  product_ref  item_date_day  item_date_month  item_date_year  \
# 0       7.313220   1670798778              1                4            2021
# 2       7.150701   1668701376              1                4            2021
# 4       7.130899    164141591              1                4            2021
# 5       6.917706       628377              1                4            2021
# 7       6.802395       611993              1                4            2021
# ...          ...          ...            ...              ...             ...
# 181635  7.106606    164141591              2                7            2020
# 181636  7.313220    164141591              2                7            2020
# 181637  7.130899    164141591              2                7            2020
# 181638  7.130899    164141591              2                7            2020
# 181639  7.122867    164141591              2                7            2020
#
#         delivery_date_day  delivery_date_month  delivery_date_year  \
# 0                       1                    7                2021
# 2                       1                    7                2021
# 4                       1                    7                2021
# 5                       1                    7                2021
# 7                       1                    7                2021
# ...                   ...                  ...                 ...
# 181635                  1                    8                2020
# 181636                  1                    8                2020
# 181637                  1                    8                2020
# 181638                  1                    8                2020
# 181639                  1                    8                2020
#
#         selling_price
# 0            6.749931
# 2            7.217443
# 4            7.001246
# 5            6.880384
# 7            7.181736
# ...               ...
# 181635       6.381816
# 181636       6.378426
# 181637       6.428105
# 181638       6.398595
# 181639       6.408529
#
# [150442 rows x 15 columns]

# %%
y
# Out:
# 0         1
# 2         1
# 4         1
# 5         1
# 7         1
#          ..
# 181635    1
# 181636    1
# 181637    1
# 181638    1
# 181639    1
# Name: status, Length: 150442, dtype: int64

# %% [markdown]
# **Over Sampling**

# %%
# !pip install -U scikit-learn
# !pip install -U imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.10/dist-packages (0.10.1)
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.11.0-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.6/235.6 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.11.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.3.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (3.2.0)
# Installing collected packages: imbalanced-learn
#   Attempting uninstall: imbalanced-learn
#     Found existing installation: imbalanced-learn 0.10.1
#     Uninstalling imbalanced-learn-0.10.1:
#       Successfully uninstalled imbalanced-learn-0.10.1
# Successfully installed imbalanced-learn-0.11.0

# %%
from imblearn.combine import SMOTETomek

model = SMOTETomek()

x_new , y_new = model.fit_resample(x,y)

x_new.shape,y_new.shape
# Out:
# ((231124, 15), (231124,))

# %%
y_new.value_counts(normalize=True)
# Out:
# 1    0.5
# 0    0.5
# Name: status, dtype: float64

# %%
x_new
# Out:
#         quantity_tons  customer  country  item_type  application  thickness  \
# 0            3.991779  30156308     28.0        5.0     2.302585   0.693147
# 1            4.235147  30341428     38.0        3.0     2.302585  -0.510826
# 2            3.314642  30165529     78.0        5.0     2.302585  -0.287682
# 3            3.473063  30202362     27.0        3.0     2.302585  -0.510826
# 4            3.035295  30211222     30.0        5.0     2.302585  -0.798508
# ...               ...       ...      ...        ...          ...        ...
# 231119       2.926565  30271717     28.0        5.0     2.302585   0.026518
# 231120       3.505786  30153509     27.0        3.0     3.713572   0.648841
# 231121       3.288207  30148629     27.0        3.0     3.713572  -0.510826
# 231122       3.249422  30165992     77.0        3.0     2.302585   0.693147
# 231123       3.534614  30198074     26.0        3.0     2.708050   2.099928
#
#            width  product_ref  item_date_day  item_date_month  item_date_year  \
# 0       7.313220   1670798778              1                4            2021
# 1       7.150701   1668701376              1                4            2021
# 2       7.130899    164141591              1                4            2021
# 3       6.917706       628377              1                4            2021
# 4       6.802395       611993              1                4            2021
# ...          ...          ...            ...              ...             ...
# 231119  6.969840       611993              2                2            2021
# 231120  7.130899    164141591             25                2            2021
# 231121  7.130899       611993             26                1            2021
# 231122  7.027934    164141591              9                9            2020
# 231123  7.313220   1671863738             23               10            2020
#
#         delivery_date_day  delivery_date_month  delivery_date_year  \
# 0                       1                    7                2021
# 1                       1                    7                2021
# 2                       1                    7                2021
# 3                       1                    7                2021
# 4                       1                    7                2021
# ...                   ...                  ...                 ...
# 231119                  1                    6                2021
# 231120                  1                    7                2021
# 231121                  1                    5                2021
# 231122                  1                   11                2020
# 231123                  1                    2                2021
#
#         selling_price
# 0            6.749931
# 1            7.217443
# 2            7.001246
# 3            6.880384
# 4            7.181736
# ...               ...
# 231119       7.108171
# 231120       6.882807
# 231121       7.110448
# 231122       6.535442
# 231123       6.583151
#
# [231124 rows x 15 columns]

# %%
y_new
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 231119    0
# 231120    0
# 231121    0
# 231122    0
# 231123    0
# Name: status, Length: 231124, dtype: int64

# %%
x_new['status'] = y_new

x_new.to_csv('classification_dataset_icm_fd.csv',index=False)

# %%
x_new
# Out:
#         quantity_tons  customer  country  item_type  application  thickness  \
# 0            3.991779  30156308     28.0        5.0     2.302585   0.693147
# 1            4.235147  30341428     38.0        3.0     2.302585  -0.510826
# 2            3.314642  30165529     78.0        5.0     2.302585  -0.287682
# 3            3.473063  30202362     27.0        3.0     2.302585  -0.510826
# 4            3.035295  30211222     30.0        5.0     2.302585  -0.798508
# ...               ...       ...      ...        ...          ...        ...
# 231119       2.926565  30271717     28.0        5.0     2.302585   0.026518
# 231120       3.505786  30153509     27.0        3.0     3.713572   0.648841
# 231121       3.288207  30148629     27.0        3.0     3.713572  -0.510826
# 231122       3.249422  30165992     77.0        3.0     2.302585   0.693147
# 231123       3.534614  30198074     26.0        3.0     2.708050   2.099928
#
#            width  product_ref  item_date_day  item_date_month  item_date_year  \
# 0       7.313220   1670798778              1                4            2021
# 1       7.150701   1668701376              1                4            2021
# 2       7.130899    164141591              1                4            2021
# 3       6.917706       628377              1                4            2021
# 4       6.802395       611993              1                4            2021
# ...          ...          ...            ...              ...             ...
# 231119  6.969840       611993              2                2            2021
# 231120  7.130899    164141591             25                2            2021
# 231121  7.130899       611993             26                1            2021
# 231122  7.027934    164141591              9                9            2020
# 231123  7.313220   1671863738             23               10            2020
#
#         delivery_date_day  delivery_date_month  delivery_date_year  \
# 0                       1                    7                2021
# 1                       1                    7                2021
# 2                       1                    7                2021
# 3                       1                    7                2021
# 4                       1                    7                2021
# ...                   ...                  ...                 ...
# 231119                  1                    6                2021
# 231120                  1                    7                2021
# 231121                  1                    5                2021
# 231122                  1                   11                2020
# 231123                  1                    2                2021
#
#         selling_price  status
# 0            6.749931       1
# 1            7.217443       1
# 2            7.001246       1
# 3            6.880384       1
# 4            7.181736       1
# ...               ...     ...
# 231119       7.108171       0
# 231120       6.882807       0
# 231121       7.110448       0
# 231122       6.535442       0
# 231123       6.583151       0
#
# [231124 rows x 16 columns]

# %% [markdown]
# ```
# # Note : Using Over sampling , ew equalised the dataset , so its now balanced
# ```

# %% [markdown]
#  **Find Best Algorithm For Classification :**

# %%
df = pd.read_csv('/content/classification_dataset_icm_fd.csv')

df
# Out:
#         quantity_tons  customer  country  item_type  application  thickness  \
# 0            3.991779  30156308     28.0        5.0     2.302585   0.693147
# 1            4.235147  30341428     38.0        3.0     2.302585  -0.510826
# 2            3.314642  30165529     78.0        5.0     2.302585  -0.287682
# 3            3.473063  30202362     27.0        3.0     2.302585  -0.510826
# 4            3.035295  30211222     30.0        5.0     2.302585  -0.798508
# ...               ...       ...      ...        ...          ...        ...
# 231119       2.926565  30271717     28.0        5.0     2.302585   0.026518
# 231120       3.505786  30153509     27.0        3.0     3.713572   0.648841
# 231121       3.288207  30148629     27.0        3.0     3.713572  -0.510826
# 231122       3.249422  30165992     77.0        3.0     2.302585   0.693147
# 231123       3.534614  30198074     26.0        3.0     2.708050   2.099928
#
#            width  product_ref  item_date_day  item_date_month  item_date_year  \
# 0       7.313220   1670798778              1                4            2021
# 1       7.150701   1668701376              1                4            2021
# 2       7.130899    164141591              1                4            2021
# 3       6.917706       628377              1                4            2021
# 4       6.802395       611993              1                4            2021
# ...          ...          ...            ...              ...             ...
# 231119  6.969840       611993              2                2            2021
# 231120  7.130899    164141591             25                2            2021
# 231121  7.130899       611993             26                1            2021
# 231122  7.027934    164141591              9                9            2020
# 231123  7.313220   1671863738             23               10            2020
#
#         delivery_date_day  delivery_date_month  delivery_date_year  \
# 0                       1                    7                2021
# 1                       1                    7                2021
# 2                       1                    7                2021
# 3                       1                    7                2021
# 4                       1                    7                2021
# ...                   ...                  ...                 ...
# 231119                  1                    6                2021
# 231120                  1                    7                2021
# 231121                  1                    5                2021
# 231122                  1                   11                2020
# 231123                  1                    2                2021
#
#         selling_price  status
# 0            6.749931       1
# 1            7.217443       1
# 2            7.001246       1
# 3            6.880384       1
# 4            7.181736       1
# ...               ...     ...
# 231119       7.108171       0
# 231120       6.882807       0
# 231121       7.110448       0
# 231122       6.535442       0
# 231123       6.583151       0
#
# [231124 rows x 16 columns]

# %%
x = df.drop('status',axis=True)
y = df['status']

# %%
x
# Out:
#         quantity_tons  customer  country  item_type  application  thickness  \
# 0            3.991779  30156308     28.0        5.0     2.302585   0.693147
# 1            4.235147  30341428     38.0        3.0     2.302585  -0.510826
# 2            3.314642  30165529     78.0        5.0     2.302585  -0.287682
# 3            3.473063  30202362     27.0        3.0     2.302585  -0.510826
# 4            3.035295  30211222     30.0        5.0     2.302585  -0.798508
# ...               ...       ...      ...        ...          ...        ...
# 231119       2.926565  30271717     28.0        5.0     2.302585   0.026518
# 231120       3.505786  30153509     27.0        3.0     3.713572   0.648841
# 231121       3.288207  30148629     27.0        3.0     3.713572  -0.510826
# 231122       3.249422  30165992     77.0        3.0     2.302585   0.693147
# 231123       3.534614  30198074     26.0        3.0     2.708050   2.099928
#
#            width  product_ref  item_date_day  item_date_month  item_date_year  \
# 0       7.313220   1670798778              1                4            2021
# 1       7.150701   1668701376              1                4            2021
# 2       7.130899    164141591              1                4            2021
# 3       6.917706       628377              1                4            2021
# 4       6.802395       611993              1                4            2021
# ...          ...          ...            ...              ...             ...
# 231119  6.969840       611993              2                2            2021
# 231120  7.130899    164141591             25                2            2021
# 231121  7.130899       611993             26                1            2021
# 231122  7.027934    164141591              9                9            2020
# 231123  7.313220   1671863738             23               10            2020
#
#         delivery_date_day  delivery_date_month  delivery_date_year  \
# 0                       1                    7                2021
# 1                       1                    7                2021
# 2                       1                    7                2021
# 3                       1                    7                2021
# 4                       1                    7                2021
# ...                   ...                  ...                 ...
# 231119                  1                    6                2021
# 231120                  1                    7                2021
# 231121                  1                    5                2021
# 231122                  1                   11                2020
# 231123                  1                    2                2021
#
#         selling_price
# 0            6.749931
# 1            7.217443
# 2            7.001246
# 3            6.880384
# 4            7.181736
# ...               ...
# 231119       7.108171
# 231120       6.882807
# 231121       7.110448
# 231122       6.535442
# 231123       6.583151
#
# [231124 rows x 15 columns]

# %%
y
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 231119    0
# 231120    0
# 231121    0
# 231122    0
# 231123    0
# Name: status, Length: 231124, dtype: int64

# %%
def model_classification(x,y,algorithm):

  for i in algorithm:

    # Split data
    xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.3)

    # Model
    model = i().fit(xtrain,ytrain)

    # Predict for train and test accuracy

    y_train_pred = model.predict(xtrain)

    y_test_pred  = model.predict(xtest)

    # Accuracy score

    training = accuracy_score(ytrain,y_train_pred)

    testing = accuracy_score(ytest,y_test_pred)

    data = {'Algorithm':i.__name__, 'Training Acuuracy':training,'Testing Accuracy':testing}

    print(data)

# %%
model_classification(x,y,[DecisionTreeClassifier,ExtraTreesClassifier,RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier,XGBClassifier])
# Out:
# {'Algorithm': 'DecisionTreeClassifier', 'Training Acuuracy': 1.0, 'Testing Accuracy': 0.9565875601949306}
# {'Algorithm': 'ExtraTreesClassifier', 'Training Acuuracy': 1.0, 'Testing Accuracy': 0.9818478041466017}
# {'Algorithm': 'RandomForestClassifier', 'Training Acuuracy': 1.0, 'Testing Accuracy': 0.9757345944231379}
# {'Algorithm': 'AdaBoostClassifier', 'Training Acuuracy': 0.7527095665929285, 'Testing Accuracy': 0.7534098445745264}
# {'Algorithm': 'GradientBoostingClassifier', 'Training Acuuracy': 0.7965198907522523, 'Testing Accuracy': 0.7971538971711987}
# {'Algorithm': 'XGBClassifier', 'Training Acuuracy': 0.939462659268139, 'Testing Accuracy': 0.9295106548631736}

# %% [markdown]
# ```
# # Note : ExtraTreesClassifier has given highest accuracy for testing as well as training
# ```

# %% [markdown]
# ## **Hyper Parameter Tuning -- Using Gridsearch CV**

# %% [markdown]
# ```
# # hyper parameter tuning is a process of selecting best parameters from set of parameters values  to increase the model performace
#
# # Grid search cv is the one of the method for hyper parameter tuning
# ```

# %% [markdown]
# **ExtraTressClassifier Hyper-parameter Tuning**

# %%
param_grid = {
    'n_estimators': [50, 100, 150],           # Number of trees in the forest
    'criterion': ['gini', 'entropy'],       # Split criterion
    'max_depth': [None, 10, 20, 30],        # Maximum depth of trees
    'min_samples_split': [2, 5, 10],       # Min samples to split an internal node
    'min_samples_leaf': [1, 2, 4],         # Min samples required at a leaf node
    'max_features': ['auto', 'sqrt', 'log2'],  # Number of features to consider
    'class_weight': [None, 'balanced'],    # Class weight
    'random_state': [42],                  # Random seed for reproducibility
}

# %%
extra_tree = ExtraTreesClassifier()

grid_search = GridSearchCV(extra_tree, param_grid, cv=5, n_jobs=-1)

grid_search.fit(x_new, y_new)

print("Best Hyperparameters:", grid_search.best_params_)

# %%
grid_search.best_score_

# %%
# Model building with Best Parameters

xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2)


# Model
model = ExtraTreesClassifier().fit(xtrain, ytrain)

# predicition

y_pred_train = model.predict(xtrain)
y_pred_test = model.predict(xtest)
accuracy_train = metrics.accuracy_score(ytrain, y_pred_train)
accuracy_test = metrics.accuracy_score(ytest, y_pred_test)
('Training accuracy :',accuracy_train),( 'Testing Accuracy :', accuracy_test)
# Out:
# (('Training accuracy :', 1.0), ('Testing Accuracy :', 0.9861763115197404))

# %%
df.columns
# Out:
# Index(['quantity_tons', 'customer', 'country', 'item_type', 'application',
#        'thickness', 'width', 'product_ref', 'item_date_day', 'item_date_month',
#        'item_date_year', 'delivery_date_day', 'delivery_date_month',
#        'delivery_date_year', 'selling_price', 'status'],
#       dtype='object')

# %%
quantity_tons = float(input('Enter the Quantity Ton value :'))

customer = float(input('Enter the customer code :'))

country = float(input('Enter the country code :'))

item_type = float(input('Enter the item type value :'))

application = float(input('Enter the application value :'))

thickness = float(input('Enter the thickness value :'))

width = float(input('Enter the width value :'))

product_ref = float(input('Enter the product ref value :'))

item_date_day = float(input('Enter the item day :'))

item_date_month = float(input('Enter the item month:'))

item_date_year = float(input('Enter the item year :'))

delivery_date_day = float(input('Enter the delivery day :'))

delivery_date_month = float(input('Enter the delivery month :'))

delivery_date_year = float(input('Enter the delivery year :'))

selling_price = float(input('Enter the selling price :'))
# Out:
# Enter the Quantity Ton value :5.047065282180851
# Enter the customer code :30287258
# Enter the country code :27
# Enter the item type value :3
# Enter the application value :2.302585092994046
# Enter the thickness value :1.01160091167848
# Enter the width value :7.1308988302963465
# Enter the product ref value :1670798778
# Enter the item day :28
# Enter the item month:3
# Enter the item year :2021
# Enter the delivery day :1
# Enter the delivery month :7
# Enter the delivery year :2021
# Enter the selling price :6.90975328164481

# %%
x = df.loc[5000]

x.values.tolist()
# Out:
# [3.824247867319961,
#  30205825.0,
#  25.0,
#  5.0,
#  2.302585092994046,
#  0.6931471805599453,
#  7.098375638590786,
#  1332077137.0,
#  24.0,
#  3.0,
#  2021.0,
#  1.0,
#  8.0,
#  2021.0,
#  6.907755278982137,
#  1.0]

# %%
x
# Out:
# quantity_tons          5.055063e+00
# country                2.700000e+01
# item_type              3.000000e+00
# application            2.302585e+00
# thickness              1.098612e+00
# width                  7.313220e+00
# product_ref            1.670799e+09
# item_date_day          2.800000e+01
# item_date_month        3.000000e+00
# item_date_year         2.021000e+03
# delivery_date_day      1.000000e+00
# delivery_date_month    7.000000e+00
# delivery_date_year     2.021000e+03
# selling_price          6.891626e+00
# status                 0.000000e+00
# Name: 3000, dtype: float64

# %%
# Provided data for prediction

# Lost

# p = [5.0550630558573335,27,3,2.302585092994046,1.0986122886681098,7.313220387090301,1670798778.0,28.0,3,2021,1,7,2021,6.891625897052253,
# ]

# WON

p = [quantity_tons, customer ,country, item_type, application,
       thickness, width, product_ref, item_date_day, item_date_month,
       item_date_year, delivery_date_day, delivery_date_month,
       delivery_date_year,
       selling_price]  # 0

# %% [markdown]
# ## **Prediction**

# %%
# Model Prediction

x = model.predict([[3.824247867319961,
 30205825.0,
 25.0,
 5.0,
 2.302585092994046,
 0.6931471805599453,
 7.098375638590786,
 1332077137.0,
 24.0,
 3.0,
 2021.0,
 1.0,
 8.0,
 2021.0,
 6.907755278982137]])

if x[0]==1:
  print()
  print('WON')
  print()
else :
  print()
  print('LOST')
  print()
# Out:
# WON
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but ExtraTreesClassifier was fitted with feature names
#   warnings.warn(

# %%
import pickle

import sklearn

sklearn.__version__
# Out:
# '1.3.1'

# %% [markdown]
# ## **Download the Pickle Model:**

# %%
with open('classification_model_icm.pkl','wb') as f:
  pickle.dump(model,f)

# %%
with open('/content/classification_model_icm.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
model
# Out:
# ExtraTreesClassifier()

# %%
# quantity_tons = float(input('Enter the Quantity Ton value :'))

# country = float(input('Enter the country code :'))

# item_type = float(input('Enter the item type value :'))

# application = float(input('Enter the application value :'))

# thickness = float(input('Enter the thickness value :'))

# width = float(input('Enter the width value :'))

# product_ref = float(input('Enter the product ref value :'))

# item_date_day = float(input('Enter the item day :'))

# item_date_month = float(input('Enter the item month:'))

# item_date_year = float(input('Enter the item year :'))

# delivery_date_day = float(input('Enter the delivery day :'))

# delivery_date_month = float(input('Enter the delivery month :'))

# delivery_date_year = float(input('Enter the delivery year :'))

# selling_price = float(input('Enter the selling price :'))


x = model.predict([p])

if x[0]==1:
  print()
  print('WON')
  print()
else :
  print()
  print('LOST')
  print()
# Out:
# LOST
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but ExtraTreesClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # **Regression Model**

# %% [markdown]
# ```
# # Aim is to predict selling price
# ```

# %%
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
import pickle

# %%
import sklearn
sklearn.__version__
# Out:
# '1.3.1'

# %%
import pandas as pd

df = pd.read_csv('/content/icm_final_cd.csv')
df
# Out:
#         quantity_tons  customer  country  status  item_type  application  \
# 0            3.991779  30156308     28.0       1        5.0     2.302585
# 1            1.259203  30209509     30.0       2        5.0     3.713572
# 2            4.235147  30341428     38.0       1        3.0     2.302585
# 3            2.216566  30209509     30.0       2        5.0     3.713572
# 4            3.314642  30165529     78.0       1        5.0     2.302585
# ...               ...       ...      ...     ...        ...          ...
# 181635       4.629691  30200854     25.0       1        5.0     3.713572
# 181636       5.337954  30200854     25.0       1        5.0     3.713572
# 181637       1.443523  30200854     25.0       1        5.0     3.713572
# 181638      -0.323075  30200854     25.0       1        5.0     3.713572
# 181639       6.008043  30200854     25.0       1        5.0     3.713572
#
#         thickness     width  product_ref  selling_price   item_date  \
# 0        0.693147  7.313220   1670798778       6.749931  2021-04-01
# 1       -0.967584  7.025538       611993       5.975038  2021-04-01
# 2       -0.510826  7.150701   1668701376       7.217443  2021-04-01
# 3       -0.967584  7.025538       611993       5.975038  2021-04-01
# 4       -0.287682  7.130899    164141591       7.001246  2021-04-01
# ...           ...       ...          ...            ...         ...
# 181635  -0.040822  7.106606    164141591       6.381816  2020-07-02
# 181636  -0.051293  7.313220    164141591       6.378426  2020-07-02
# 181637  -0.342490  7.130899    164141591       6.428105  2020-07-02
# 181638  -0.162519  7.130899    164141591       6.398595  2020-07-02
# 181639  -0.342490  7.122867    164141591       6.408529  2020-07-02
#
#        delivery_date_pred  item_date_day  item_date_month  item_date_year  \
# 0              2021-07-01              1                4            2021
# 1              2021-07-01              1                4            2021
# 2              2021-07-01              1                4            2021
# 3              2021-07-01              1                4            2021
# 4              2021-07-01              1                4            2021
# ...                   ...            ...              ...             ...
# 181635         2020-08-01              2                7            2020
# 181636         2020-08-01              2                7            2020
# 181637         2020-08-01              2                7            2020
# 181638         2020-08-01              2                7            2020
# 181639         2020-08-01              2                7            2020
#
#         delivery_date_day  delivery_date_month  delivery_date_year
# 0                       1                    7                2021
# 1                       1                    7                2021
# 2                       1                    7                2021
# 3                       1                    7                2021
# 4                       1                    7                2021
# ...                   ...                  ...                 ...
# 181635                  1                    8                2020
# 181636                  1                    8                2020
# 181637                  1                    8                2020
# 181638                  1                    8                2020
# 181639                  1                    8                2020
#
# [181640 rows x 18 columns]

# %%
df.columns
# Out:
# Index(['quantity_tons', 'customer', 'country', 'status', 'item_type',
#        'application', 'thickness', 'width', 'product_ref', 'selling_price',
#        'item_date', 'delivery_date_pred', 'item_date_day', 'item_date_month',
#        'item_date_year', 'delivery_date_day', 'delivery_date_month',
#        'delivery_date_year'],
#       dtype='object')

# %% [markdown]
# **Split Data**

# %%
df = df[['quantity_tons', 'customer', 'country', 'item_type',
       'application', 'thickness', 'width', 'product_ref',
        'item_date_day', 'item_date_month',
       'item_date_year', 'delivery_date_day', 'delivery_date_month',
       'delivery_date_year', 'status','selling_price']]

# %%
x = df.drop('selling_price',axis=1)

y = df['selling_price']

# %%
x
# Out:
#         quantity_tons  customer  country  item_type  application  thickness  \
# 0            3.991779  30156308     28.0        5.0     2.302585   0.693147
# 1            1.259203  30209509     30.0        5.0     3.713572  -0.967584
# 2            4.235147  30341428     38.0        3.0     2.302585  -0.510826
# 3            2.216566  30209509     30.0        5.0     3.713572  -0.967584
# 4            3.314642  30165529     78.0        5.0     2.302585  -0.287682
# ...               ...       ...      ...        ...          ...        ...
# 181635       4.629691  30200854     25.0        5.0     3.713572  -0.040822
# 181636       5.337954  30200854     25.0        5.0     3.713572  -0.051293
# 181637       1.443523  30200854     25.0        5.0     3.713572  -0.342490
# 181638      -0.323075  30200854     25.0        5.0     3.713572  -0.162519
# 181639       6.008043  30200854     25.0        5.0     3.713572  -0.342490
#
#            width  product_ref  item_date_day  item_date_month  item_date_year  \
# 0       7.313220   1670798778              1                4            2021
# 1       7.025538       611993              1                4            2021
# 2       7.150701   1668701376              1                4            2021
# 3       7.025538       611993              1                4            2021
# 4       7.130899    164141591              1                4            2021
# ...          ...          ...            ...              ...             ...
# 181635  7.106606    164141591              2                7            2020
# 181636  7.313220    164141591              2                7            2020
# 181637  7.130899    164141591              2                7            2020
# 181638  7.130899    164141591              2                7            2020
# 181639  7.122867    164141591              2                7            2020
#
#         delivery_date_day  delivery_date_month  delivery_date_year  status
# 0                       1                    7                2021       1
# 1                       1                    7                2021       2
# 2                       1                    7                2021       1
# 3                       1                    7                2021       2
# 4                       1                    7                2021       1
# ...                   ...                  ...                 ...     ...
# 181635                  1                    8                2020       1
# 181636                  1                    8                2020       1
# 181637                  1                    8                2020       1
# 181638                  1                    8                2020       1
# 181639                  1                    8                2020       1
#
# [181640 rows x 15 columns]

# %%
y
# Out:
# 0         6.749931
# 1         5.975038
# 2         7.217443
# 3         5.975038
# 4         7.001246
#             ...
# 181635    6.381816
# 181636    6.378426
# 181637    6.428105
# 181638    6.398595
# 181639    6.408529
# Name: selling_price, Length: 181640, dtype: float64

# %%
def model_regression(x,y,algorithm):
  for i in algorithm:


    xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2)


    model = i().fit(xtrain,ytrain)


    # predict for train and test accuracy

    y_train_pred = model.predict(xtrain)


    y_test_pred  = model.predict(xtest)

    # Accuracy score

    training = r2_score(ytrain,y_train_pred)

    testing = r2_score(ytest,y_test_pred)

    data = {'Algorithm':i.__name__, 'Training R2 Score':training,'Testing R2 Score':testing}

    print(data)

# %%
model_regression(x,y,[DecisionTreeRegressor,ExtraTreesRegressor,RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor,XGBRegressor])
# Out:
# {'Algorithm': 'DecisionTreeRegressor', 'Training R2 Score': 0.9999268653659622, 'Testing R2 Score': 0.9195031279808634}
# {'Algorithm': 'ExtraTreesRegressor', 'Training R2 Score': 0.9999219938363896, 'Testing R2 Score': 0.9563042116447812}
# {'Algorithm': 'RandomForestRegressor', 'Training R2 Score': 0.9938673205663499, 'Testing R2 Score': 0.9605673390182}
# {'Algorithm': 'AdaBoostRegressor', 'Training R2 Score': 0.625650703182868, 'Testing R2 Score': 0.6277117783292192}
# {'Algorithm': 'GradientBoostingRegressor', 'Training R2 Score': 0.8867690849125366, 'Testing R2 Score': 0.8892807227696046}
# {'Algorithm': 'XGBRegressor', 'Training R2 Score': 0.9512432628346805, 'Testing R2 Score': 0.9464880850232799}

# %% [markdown]
# **Hyper parameter Tuning Using grid-search cv**

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.2,random_state=42)

param_grid_r = {'max_depth'      : [2, 5, 10, 20],
              'min_samples_split': [2, 5, 10],
              'min_samples_leaf' : [1, 2, 4],
              'max_features'     : ['sqrt', 'log2', None]}

grid_search_r = GridSearchCV(estimator=RandomForestRegressor(), param_grid=param_grid_r, cv=5, n_jobs=-1)
grid_search_r.fit(xtrain, ytrain)

# %%
grid_search_r.best_params_,grid_search_r.best_score_

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.2)

model = ExtraTreesRegressor().fit(xtrain, ytrain)

y_pred_train = model.predict(xtrain)

y_pred_test = model.predict(xtest)

r2_train = r2_score(ytrain, y_pred_train)

r2_test = r2_score(ytest, y_pred_test)

r2_train, r2_test

# with classifiction dataset

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.2)

model = ExtraTreesRegressor().fit(xtrain, ytrain)

y_pred_train = model.predict(xtrain)

y_pred_test = model.predict(xtest)

r2_train = r2_score(ytrain, y_pred_train)

r2_test = r2_score(ytest, y_pred_test)

r2_train, r2_test

# with normal df
# Out:
# (0.9999122396303116, 0.9565546761695108)

# %%
quantity_tons = float(input('Enter the Quantity Ton value :'))

customer = float(input('enter the cusomer value'))

country = float(input('Enter the country code :'))

status = float(input('Enter the  status :'))

item_type = float(input('Enter the item type value :'))

application = float(input('Enter the application value :'))

thickness = float(input('Enter the thickness value :'))

width = float(input('Enter the width value :'))

product_ref = float(input('Enter the product ref value :'))

item_date_day = float(input('Enter the item day :'))

item_date_month = float(input('Enter the item month:'))

item_date_year = float(input('Enter the item year :'))

delivery_date_day = float(input('Enter the delivery day :'))

delivery_date_month = float(input('Enter the delivery month :'))

delivery_date_year = float(input('Enter the delivery year :'))
# Out:
# Enter the Quantity Ton value :1.849617
# enter the cusomer value30160378
# Enter the country code :78
# Enter the  status :2
# Enter the item type value :5
# Enter the application value :3.713572
# Enter the thickness value :-0.356675
# Enter the width value :7.129298
# Enter the product ref value :611993
# Enter the item day :10
# Enter the item month:3
# Enter the item year :2021
# Enter the delivery day :1
# Enter the delivery month :7
# Enter the delivery year :2021

# %%
df.loc[10000]
# Out:
# quantity_tons            1.849617
# customer                 30160378
# country                      78.0
# status                          2
# item_type                     5.0
# application              3.713572
# thickness               -0.356675
# width                    7.129298
# product_ref                611993
# selling_price            5.975038
# item_date              2021-03-19
# delivery_date_pred     2021-07-01
# item_date_day                  19
# item_date_month                 3
# item_date_year               2021
# delivery_date_day               1
# delivery_date_month             7
# delivery_date_year           2021
# Name: 10000, dtype: object

# %%
x = df.loc[1000]

x.values.tolist()
# Out:
# [4.571440618970477,
#  30271289.0,
#  28.0,
#  5.0,
#  2.70805020110221,
#  1.791759469228055,
#  7.313220387090301,
#  1670798778.0,
#  31.0,
#  3.0,
#  2021.0,
#  1.0,
#  9.0,
#  2021.0,
#  1.0,
#  6.880384082186005]

# %%
selling_price = model.predict([[4.571440618970477,
 30271289.0,
 28.0,
 5.0,
 2.70805020110221,
 1.791759469228055,
 7.313220387090301,
 1670798778.0,
 31.0,
 3.0,
 2021.0,
 1.0,
 9.0,
 2021.0,
 1.0]])

import numpy as np

f'predicted selling price : {(np.exp(selling_price))}' f'actual price {np.exp(6.880384082186005)}'
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but ExtraTreesRegressor was fitted with feature names
#   warnings.warn(
# 'predicted selling price : [973.]actual price 972.9999999999999'

# %% [markdown]
# ## **Download Pickle Model**

# %%
with open('regression_model.pkl', 'wb') as f:
    pickle.dump(model, f)

# %%
with open('/content/regression_model.pkl', 'rb') as f:
    model = pickle.load(f)

# %% [markdown]
# ## **Prediction**

# %%
sp = [np.log(54.1511386169278),30156308,28,5,np.log(10),np.log(2),np.log(1500),1670798778,1,4,2021,1,7,2021,1]

# %%
sell = model.predict([sp])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but ExtraTreesRegressor was fitted with feature names
#   warnings.warn(

# %%
np.exp(sell)
# Out:
# array([854.])

# %%
# Sellling -- manufacturer year plays major role -- item year   , type of item -- item_type , application -- code

# %% [markdown]
# ```
#                                                                               Finished
# ```
